# %%
# Import the dependencies.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# !pip install citipy
# Out:
# Requirement already satisfied: citipy in c:\programdata\anaconda3\lib\site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in c:\programdata\anaconda3\lib\site-packages (from citipy) (0.16)

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1400)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1400)
lat_lngs = zip(lats, lngs)
# Add thelatitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 607

# %%
# API created

# %%
# The JavaScript Object Notation Format for API Data

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

# Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
    # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
    # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | luderitz
# Processing Record 2 of Set 1 | hobart
# Processing Record 3 of Set 1 | chegdomyn
# Processing Record 4 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 5 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 6 of Set 1 | sisimiut
# Processing Record 7 of Set 1 | busselton
# Processing Record 8 of Set 1 | jamestown
# Processing Record 9 of Set 1 | port alfred
# Processing Record 10 of Set 1 | waitara
# Processing Record 11 of Set 1 | crofton
# Processing Record 12 of Set 1 | ushuaia
# Processing Record 13 of Set 1 | albany
# Processing Record 14 of Set 1 | qaanaaq
# Processing Record 15 of Set 1 | bambous virieux
# Processing Record 16 of Set 1 | khatanga
# Processing Record 17 of Set 1 | puerto escondido
# Processing Record 18 of Set 1 | hami
# Processing Record 19 of Set 1 | okhotsk
# Processing Record 20 of Set 1 | talnakh
# Processing Record 21 of Set 1 | hirado
# Processing Record 22 of Set 1 | rikitea
# Processing Record 23 of Set 1 | mahebourg
# Processing Record 24 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 25 of Set 1 | natitingou
# Processing Record 26 of Set 1 | callaway
# Processing Record 27 of Set 1 | victoria
# Processing Record 28 of Set 1 | mount gambier
# Processing Record 29 of Set 1 | butaritari
# Processing Record 30 of Set 1 | atuona
# Processing Record 31 of Set 1 | avarua
# Processing Record 32 of Set 1 | saint-joseph
# Processing Record 33 of Set 1 | hithadhoo
# Processing Record 34 of Set 1 | barrow
# Processing Record 35 of Set 1 | hilo
# Processing Record 36 of Set 1 | palimbang
# Processing Record 37 of Set 1 | carnarvon
# Processing Record 38 of Set 1 | chuy
# Processing Record 39 of Set 1 | severo-kurilsk
# Processing Record 40 of Set 1 | manoel urbano
# Processing Record 41 of Set 1 | punta arenas
# Processing Record 42 of Set 1 | tiksi
# Processing Record 43 of Set 1 | trairi
# Processing Record 44 of Set 1 | dakar
# Processing Record 45 of Set 1 | nome
# Processing Record 46 of Set 1 | castro
# Processing Record 47 of Set 1 | tazovskiy
# Processing Record 48 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 49 of Set 1 | esil
# Processing Record 50 of Set 1 | berlevag
# Processing Record 1 of Set 2 | port hardy
# Processing Record 2 of Set 2 | barentu
# Processing Record 3 of Set 2 | san juan
# Processing Record 4 of Set 2 | rocha
# Processing Record 5 of Set 2 | green river
# Processing Record 6 of Set 2 | port elizabeth
# Processing Record 7 of Set 2 | emba
# Processing Record 8 of Set 2 | kodiak
# Processing Record 9 of Set 2 | bredasdorp
# Processing Record 10 of Set 2 | cape town
# Processing Record 11 of Set 2 | torbay
# Processing Record 12 of Set 2 | tuktoyaktuk
# Processing Record 13 of Set 2 | guerrero negro
# Processing Record 14 of Set 2 | vaini
# Processing Record 15 of Set 2 | sovetskaya gavan
# Processing Record 16 of Set 2 | shelburne
# Processing Record 17 of Set 2 | georgetown
# Processing Record 18 of Set 2 | bluff
# Processing Record 19 of Set 2 | margate
# Processing Record 20 of Set 2 | ponta do sol
# Processing Record 21 of Set 2 | diamantino
# Processing Record 22 of Set 2 | kyabram
# Processing Record 23 of Set 2 | nizhniy tsasuchey
# Processing Record 24 of Set 2 | valparaiso
# Processing Record 25 of Set 2 | oyama
# Processing Record 26 of Set 2 | karauzyak
# City not found. Skipping...
# Processing Record 27 of Set 2 | isangel
# Processing Record 28 of Set 2 | rapar
# Processing Record 29 of Set 2 | kapaa
# Processing Record 30 of Set 2 | hanna
# Processing Record 31 of Set 2 | roald
# Processing Record 32 of Set 2 | saint-philippe
# Processing Record 33 of Set 2 | geraldton
# Processing Record 34 of Set 2 | manokwari
# Processing Record 35 of Set 2 | nikolskoye
# Processing Record 36 of Set 2 | opuwo
# Processing Record 37 of Set 2 | lorengau
# Processing Record 38 of Set 2 | kedarnath
# City not found. Skipping...
# Processing Record 39 of Set 2 | east london
# Processing Record 40 of Set 2 | lebu
# Processing Record 41 of Set 2 | clyde river
# Processing Record 42 of Set 2 | camana
# Processing Record 43 of Set 2 | port-cartier
# Processing Record 44 of Set 2 | saint george
# Processing Record 45 of Set 2 | mataura
# Processing Record 46 of Set 2 | corinto
# Processing Record 47 of Set 2 | ajdabiya
# Processing Record 48 of Set 2 | lamar
# Processing Record 49 of Set 2 | grindavik
# Processing Record 50 of Set 2 | fortuna
# Processing Record 1 of Set 3 | barra do garcas
# Processing Record 2 of Set 3 | lasa
# Processing Record 3 of Set 3 | yar-sale
# Processing Record 4 of Set 3 | stutterheim
# Processing Record 5 of Set 3 | smirnykh
# Processing Record 6 of Set 3 | comana
# Processing Record 7 of Set 3 | puerto ayora
# Processing Record 8 of Set 3 | deming
# Processing Record 9 of Set 3 | mar del plata
# Processing Record 10 of Set 3 | thompson
# Processing Record 11 of Set 3 | raga
# Processing Record 12 of Set 3 | ruteng
# Processing Record 13 of Set 3 | upernavik
# Processing Record 14 of Set 3 | kavaratti
# Processing Record 15 of Set 3 | naica
# Processing Record 16 of Set 3 | hermanus
# Processing Record 17 of Set 3 | yellowknife
# Processing Record 18 of Set 3 | buqayq
# City not found. Skipping...
# Processing Record 19 of Set 3 | tibu
# Processing Record 20 of Set 3 | mrkonjic grad
# Processing Record 21 of Set 3 | saskylakh
# Processing Record 22 of Set 3 | oussouye
# Processing Record 23 of Set 3 | shache
# Processing Record 24 of Set 3 | kavieng
# Processing Record 25 of Set 3 | ca mau
# Processing Record 26 of Set 3 | leningradskiy
# Processing Record 27 of Set 3 | savannah bight
# Processing Record 28 of Set 3 | vila
# Processing Record 29 of Set 3 | mitsamiouli
# Processing Record 30 of Set 3 | norman wells
# Processing Record 31 of Set 3 | viedma
# Processing Record 32 of Set 3 | san quintin
# Processing Record 33 of Set 3 | camacha
# Processing Record 34 of Set 3 | pevek
# Processing Record 35 of Set 3 | ilulissat
# Processing Record 36 of Set 3 | bethel
# Processing Record 37 of Set 3 | sept-iles
# Processing Record 38 of Set 3 | ribeira grande
# Processing Record 39 of Set 3 | iqaluit
# Processing Record 40 of Set 3 | beidao
# Processing Record 41 of Set 3 | oktyabrskoye
# Processing Record 42 of Set 3 | khani
# Processing Record 43 of Set 3 | tahta
# Processing Record 44 of Set 3 | zhuhai
# Processing Record 45 of Set 3 | vila franca do campo
# Processing Record 46 of Set 3 | gummidipundi
# Processing Record 47 of Set 3 | longyearbyen
# Processing Record 48 of Set 3 | hambantota
# Processing Record 49 of Set 3 | caxias
# Processing Record 50 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 1 of Set 4 | kahului
# Processing Record 2 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 3 of Set 4 | hasaki
# Processing Record 4 of Set 4 | enshi
# Processing Record 5 of Set 4 | almenevo
# City not found. Skipping...
# Processing Record 6 of Set 4 | plettenberg bay
# Processing Record 7 of Set 4 | moen
# Processing Record 8 of Set 4 | tono
# Processing Record 9 of Set 4 | boqueron
# Processing Record 10 of Set 4 | unai
# Processing Record 11 of Set 4 | rongcheng
# Processing Record 12 of Set 4 | sao felix do xingu
# Processing Record 13 of Set 4 | basco
# Processing Record 14 of Set 4 | barra patuca
# Processing Record 15 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 16 of Set 4 | jacareacanga
# Processing Record 17 of Set 4 | diapaga
# Processing Record 18 of Set 4 | hamilton
# Processing Record 19 of Set 4 | melioratorov
# Processing Record 20 of Set 4 | casa nova
# Processing Record 21 of Set 4 | tuatapere
# Processing Record 22 of Set 4 | sur
# Processing Record 23 of Set 4 | swan river
# Processing Record 24 of Set 4 | mocoa
# Processing Record 25 of Set 4 | san anselmo
# Processing Record 26 of Set 4 | sechura
# Processing Record 27 of Set 4 | khasan
# Processing Record 28 of Set 4 | cozumel
# Processing Record 29 of Set 4 | luis correia
# Processing Record 30 of Set 4 | lucapa
# Processing Record 31 of Set 4 | gayeri
# Processing Record 32 of Set 4 | birecik
# Processing Record 33 of Set 4 | codrington
# Processing Record 34 of Set 4 | ariquemes
# Processing Record 35 of Set 4 | babanusah
# City not found. Skipping...
# Processing Record 36 of Set 4 | chico
# Processing Record 37 of Set 4 | hoquiam
# Processing Record 38 of Set 4 | finspang
# Processing Record 39 of Set 4 | nguiu
# City not found. Skipping...
# Processing Record 40 of Set 4 | bathurst
# Processing Record 41 of Set 4 | monster
# Processing Record 42 of Set 4 | ladario
# Processing Record 43 of Set 4 | touros
# Processing Record 44 of Set 4 | sao filipe
# Processing Record 45 of Set 4 | itaituba
# Processing Record 46 of Set 4 | sri madhopur
# Processing Record 47 of Set 4 | guane
# Processing Record 48 of Set 4 | svetlyy
# Processing Record 49 of Set 4 | artyom
# Processing Record 50 of Set 4 | sabla
# Processing Record 1 of Set 5 | hualmay
# Processing Record 2 of Set 5 | elliot lake
# Processing Record 3 of Set 5 | bella vista
# Processing Record 4 of Set 5 | general delgado
# Processing Record 5 of Set 5 | lardos
# Processing Record 6 of Set 5 | kalmunai
# Processing Record 7 of Set 5 | banmo
# City not found. Skipping...
# Processing Record 8 of Set 5 | coquimbo
# Processing Record 9 of Set 5 | hirara
# Processing Record 10 of Set 5 | sola
# Processing Record 11 of Set 5 | ekibastuz
# Processing Record 12 of Set 5 | huilong
# Processing Record 13 of Set 5 | cherskiy
# Processing Record 14 of Set 5 | tasbuget
# City not found. Skipping...
# Processing Record 15 of Set 5 | kuryk
# Processing Record 16 of Set 5 | promyshlennaya
# Processing Record 17 of Set 5 | salaya
# Processing Record 18 of Set 5 | gunjur
# Processing Record 19 of Set 5 | boljevac
# Processing Record 20 of Set 5 | gravdal
# Processing Record 21 of Set 5 | baculin
# Processing Record 22 of Set 5 | najran
# Processing Record 23 of Set 5 | abashiri
# Processing Record 24 of Set 5 | tongren
# Processing Record 25 of Set 5 | lumeje
# Processing Record 26 of Set 5 | chapais
# Processing Record 27 of Set 5 | broken hill
# Processing Record 28 of Set 5 | khudumelapye
# Processing Record 29 of Set 5 | bloomingdale
# Processing Record 30 of Set 5 | ozgon
# City not found. Skipping...
# Processing Record 31 of Set 5 | ayan
# Processing Record 32 of Set 5 | sorvag
# City not found. Skipping...
# Processing Record 33 of Set 5 | aswan
# Processing Record 34 of Set 5 | sao joao da barra
# Processing Record 35 of Set 5 | juegang
# Processing Record 36 of Set 5 | nizwa
# Processing Record 37 of Set 5 | nouadhibou
# Processing Record 38 of Set 5 | sakaiminato
# Processing Record 39 of Set 5 | havre-saint-pierre
# Processing Record 40 of Set 5 | road town
# Processing Record 41 of Set 5 | sinnai
# Processing Record 42 of Set 5 | port moresby
# Processing Record 43 of Set 5 | whitefish
# Processing Record 44 of Set 5 | hervey bay
# Processing Record 45 of Set 5 | tkvarcheli
# City not found. Skipping...
# Processing Record 46 of Set 5 | katsuura
# Processing Record 47 of Set 5 | shuyskoye
# Processing Record 48 of Set 5 | middelkerke
# Processing Record 49 of Set 5 | santa cruz cabralia
# Processing Record 50 of Set 5 | manta
# Processing Record 1 of Set 6 | lavrentiya
# Processing Record 2 of Set 6 | mangai
# Processing Record 3 of Set 6 | kamina
# Processing Record 4 of Set 6 | tres barras
# Processing Record 5 of Set 6 | imeni poliny osipenko
# Processing Record 6 of Set 6 | esperance
# Processing Record 7 of Set 6 | kulhudhuffushi
# Processing Record 8 of Set 6 | haines junction
# Processing Record 9 of Set 6 | michigan city
# Processing Record 10 of Set 6 | coos bay
# Processing Record 11 of Set 6 | mariestad
# Processing Record 12 of Set 6 | nanortalik
# Processing Record 13 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 14 of Set 6 | naze
# Processing Record 15 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 16 of Set 6 | willmar
# Processing Record 17 of Set 6 | lompoc
# Processing Record 18 of Set 6 | pombas
# Processing Record 19 of Set 6 | whitehorse
# Processing Record 20 of Set 6 | ijaki
# City not found. Skipping...
# Processing Record 21 of Set 6 | novouzensk
# Processing Record 22 of Set 6 | crestview
# Processing Record 23 of Set 6 | rassvet
# Processing Record 24 of Set 6 | birin
# Processing Record 25 of Set 6 | tigil
# Processing Record 26 of Set 6 | souillac
# Processing Record 27 of Set 6 | chor
# Processing Record 28 of Set 6 | biak
# Processing Record 29 of Set 6 | cayenne
# Processing Record 30 of Set 6 | korem
# Processing Record 31 of Set 6 | constitucion
# Processing Record 32 of Set 6 | bilibino
# Processing Record 33 of Set 6 | wodonga
# Processing Record 34 of Set 6 | hovd
# Processing Record 35 of Set 6 | new norfolk
# Processing Record 36 of Set 6 | santa cruz de tenerife
# Processing Record 37 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 38 of Set 6 | satitoa
# City not found. Skipping...
# Processing Record 39 of Set 6 | parana
# Processing Record 40 of Set 6 | parrita
# Processing Record 41 of Set 6 | dongsheng
# Processing Record 42 of Set 6 | bowling green
# Processing Record 43 of Set 6 | mangaratiba
# Processing Record 44 of Set 6 | kuytun
# Processing Record 45 of Set 6 | umm lajj
# Processing Record 46 of Set 6 | provideniya
# Processing Record 47 of Set 6 | baracoa
# Processing Record 48 of Set 6 | baghdad
# Processing Record 49 of Set 6 | kruisfontein
# Processing Record 50 of Set 6 | severobaykalsk
# Processing Record 1 of Set 7 | dunedin
# Processing Record 2 of Set 7 | airai
# Processing Record 3 of Set 7 | sawakin
# Processing Record 4 of Set 7 | darlawn
# Processing Record 5 of Set 7 | senno
# Processing Record 6 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 7 of Set 7 | barcelos
# Processing Record 8 of Set 7 | half moon bay
# Processing Record 9 of Set 7 | kondinskoye
# Processing Record 10 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 11 of Set 7 | polson
# Processing Record 12 of Set 7 | port hedland
# Processing Record 13 of Set 7 | zhukovo
# Processing Record 14 of Set 7 | russell
# Processing Record 15 of Set 7 | marsh harbour
# Processing Record 16 of Set 7 | bengkulu
# Processing Record 17 of Set 7 | high level
# Processing Record 18 of Set 7 | contai
# Processing Record 19 of Set 7 | comarapa
# Processing Record 20 of Set 7 | luena
# Processing Record 21 of Set 7 | marquette
# Processing Record 22 of Set 7 | gigmoto
# Processing Record 23 of Set 7 | george town
# Processing Record 24 of Set 7 | bay roberts
# Processing Record 25 of Set 7 | port blair
# Processing Record 26 of Set 7 | darnah
# Processing Record 27 of Set 7 | aitape
# Processing Record 28 of Set 7 | tasiilaq
# Processing Record 29 of Set 7 | strezhevoy
# Processing Record 30 of Set 7 | belousovka
# Processing Record 31 of Set 7 | yeppoon
# Processing Record 32 of Set 7 | pimentel
# Processing Record 33 of Set 7 | hofu
# Processing Record 34 of Set 7 | parrsboro
# Processing Record 35 of Set 7 | college
# Processing Record 36 of Set 7 | arraial do cabo
# Processing Record 37 of Set 7 | san jeronimo
# Processing Record 38 of Set 7 | meulaboh
# Processing Record 39 of Set 7 | ilovlya
# Processing Record 40 of Set 7 | faanui
# Processing Record 41 of Set 7 | portland
# Processing Record 42 of Set 7 | sorland
# Processing Record 43 of Set 7 | stoyba
# City not found. Skipping...
# Processing Record 44 of Set 7 | beringovskiy
# Processing Record 45 of Set 7 | glendive
# Processing Record 46 of Set 7 | tura
# Processing Record 47 of Set 7 | saint-pierre
# Processing Record 48 of Set 7 | suining
# Processing Record 49 of Set 7 | vinh long
# Processing Record 50 of Set 7 | lagoa
# Processing Record 1 of Set 8 | jinchang
# Processing Record 2 of Set 8 | usinsk
# Processing Record 3 of Set 8 | dingle
# Processing Record 4 of Set 8 | paoua
# Processing Record 5 of Set 8 | vyshneve
# Processing Record 6 of Set 8 | nantucket
# Processing Record 7 of Set 8 | taga dzong
# City not found. Skipping...
# Processing Record 8 of Set 8 | storforshei
# Processing Record 9 of Set 8 | mirador
# Processing Record 10 of Set 8 | utiroa
# City not found. Skipping...
# Processing Record 11 of Set 8 | maloshuyka
# City not found. Skipping...
# Processing Record 12 of Set 8 | la sarre
# Processing Record 13 of Set 8 | przeworsk
# Processing Record 14 of Set 8 | vardo
# Processing Record 15 of Set 8 | deputatskiy
# Processing Record 16 of Set 8 | terrace bay
# Processing Record 17 of Set 8 | peniche
# Processing Record 18 of Set 8 | ahipara
# Processing Record 19 of Set 8 | dawlatabad
# Processing Record 20 of Set 8 | prince george
# Processing Record 21 of Set 8 | pacific grove
# Processing Record 22 of Set 8 | aranos
# Processing Record 23 of Set 8 | oranjemund
# Processing Record 24 of Set 8 | mpanda
# Processing Record 25 of Set 8 | mormugao
# Processing Record 26 of Set 8 | barwadih
# Processing Record 27 of Set 8 | redmond
# Processing Record 28 of Set 8 | salalah
# Processing Record 29 of Set 8 | alice springs
# Processing Record 30 of Set 8 | aksu
# Processing Record 31 of Set 8 | kegayli
# City not found. Skipping...
# Processing Record 32 of Set 8 | san cristobal
# Processing Record 33 of Set 8 | anloga
# Processing Record 34 of Set 8 | den helder
# Processing Record 35 of Set 8 | palasa
# Processing Record 36 of Set 8 | kushiro
# Processing Record 37 of Set 8 | husavik
# Processing Record 38 of Set 8 | sitka
# Processing Record 39 of Set 8 | laguna
# Processing Record 40 of Set 8 | honiara
# Processing Record 41 of Set 8 | ancud
# Processing Record 42 of Set 8 | odweyne
# Processing Record 43 of Set 8 | shenandoah
# Processing Record 44 of Set 8 | thomastown
# Processing Record 45 of Set 8 | songea
# Processing Record 46 of Set 8 | dikson
# Processing Record 47 of Set 8 | matagami
# Processing Record 48 of Set 8 | cabo san lucas
# Processing Record 49 of Set 8 | poya
# Processing Record 50 of Set 8 | yulara
# Processing Record 1 of Set 9 | nisia floresta
# Processing Record 2 of Set 9 | agadez
# Processing Record 3 of Set 9 | krasnyy yar
# Processing Record 4 of Set 9 | sabang
# Processing Record 5 of Set 9 | kenitra
# Processing Record 6 of Set 9 | warrington
# Processing Record 7 of Set 9 | kryve ozero
# Processing Record 8 of Set 9 | chokurdakh
# Processing Record 9 of Set 9 | gondar
# Processing Record 10 of Set 9 | klaksvik
# Processing Record 11 of Set 9 | kaseda
# Processing Record 12 of Set 9 | broome
# Processing Record 13 of Set 9 | wanxian
# Processing Record 14 of Set 9 | lepe
# Processing Record 15 of Set 9 | socorro
# Processing Record 16 of Set 9 | siilinjarvi
# Processing Record 17 of Set 9 | namibe
# Processing Record 18 of Set 9 | viramgam
# Processing Record 19 of Set 9 | mandurah
# Processing Record 20 of Set 9 | alofi
# Processing Record 21 of Set 9 | houma
# Processing Record 22 of Set 9 | tual
# Processing Record 23 of Set 9 | kushikino
# Processing Record 24 of Set 9 | barinas
# Processing Record 25 of Set 9 | vao
# Processing Record 26 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 27 of Set 9 | pisco
# Processing Record 28 of Set 9 | araouane
# Processing Record 29 of Set 9 | san buenaventura
# Processing Record 30 of Set 9 | hammerfest
# Processing Record 31 of Set 9 | matamoros
# Processing Record 32 of Set 9 | tilichiki
# Processing Record 33 of Set 9 | tangshan
# Processing Record 34 of Set 9 | dezhou
# Processing Record 35 of Set 9 | healesville
# Processing Record 36 of Set 9 | padang
# Processing Record 37 of Set 9 | thunder bay
# Processing Record 38 of Set 9 | kyren
# Processing Record 39 of Set 9 | san andres
# Processing Record 40 of Set 9 | caravelas
# Processing Record 41 of Set 9 | gushikawa
# Processing Record 42 of Set 9 | knysna
# Processing Record 43 of Set 9 | andenes
# Processing Record 44 of Set 9 | noshiro
# Processing Record 45 of Set 9 | east lansing
# Processing Record 46 of Set 9 | kabul
# Processing Record 47 of Set 9 | nuuk
# Processing Record 48 of Set 9 | vila velha
# Processing Record 49 of Set 9 | te anau
# Processing Record 50 of Set 9 | petropavlovskoye
# Processing Record 1 of Set 10 | yarmouth
# Processing Record 2 of Set 10 | ishigaki
# Processing Record 3 of Set 10 | barguzin
# Processing Record 4 of Set 10 | jasper
# Processing Record 5 of Set 10 | labutta
# City not found. Skipping...
# Processing Record 6 of Set 10 | cheuskiny
# City not found. Skipping...
# Processing Record 7 of Set 10 | coxim
# Processing Record 8 of Set 10 | thano bula khan
# City not found. Skipping...
# Processing Record 9 of Set 10 | champerico
# Processing Record 10 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 11 of Set 10 | komsomolskiy
# Processing Record 12 of Set 10 | grand river south east
# City not found. Skipping...
# Processing Record 13 of Set 10 | mehamn
# Processing Record 14 of Set 10 | praia
# Processing Record 15 of Set 10 | langfang
# Processing Record 16 of Set 10 | solnechnyy
# Processing Record 17 of Set 10 | columbus
# Processing Record 18 of Set 10 | sinnamary
# Processing Record 19 of Set 10 | roebourne
# Processing Record 20 of Set 10 | maceio
# Processing Record 21 of Set 10 | juan lacaze
# Processing Record 22 of Set 10 | bullhead city
# Processing Record 23 of Set 10 | gizo
# Processing Record 24 of Set 10 | santa isabel do rio negro
# Processing Record 25 of Set 10 | robertsport
# Processing Record 26 of Set 10 | kisangani
# Processing Record 27 of Set 10 | fort morgan
# Processing Record 28 of Set 10 | nyurba
# Processing Record 29 of Set 10 | dergaon
# Processing Record 30 of Set 10 | cidreira
# Processing Record 31 of Set 10 | arlit
# Processing Record 32 of Set 10 | graaff-reinet
# Processing Record 33 of Set 10 | kuche
# City not found. Skipping...
# Processing Record 34 of Set 10 | el real de santa maria
# Processing Record 35 of Set 10 | nabire
# Processing Record 36 of Set 10 | campbell river
# Processing Record 37 of Set 10 | taltal
# Processing Record 38 of Set 10 | ngunguru
# Processing Record 39 of Set 10 | pilar
# Processing Record 40 of Set 10 | brasilia de minas
# Processing Record 41 of Set 10 | bud
# Processing Record 42 of Set 10 | dudinka
# Processing Record 43 of Set 10 | lluta
# Processing Record 44 of Set 10 | santa isabel
# Processing Record 45 of Set 10 | voh
# Processing Record 46 of Set 10 | jakar
# Processing Record 47 of Set 10 | jiroft
# City not found. Skipping...
# Processing Record 48 of Set 10 | aloleng
# Processing Record 49 of Set 10 | merauke
# Processing Record 50 of Set 10 | karratha
# Processing Record 1 of Set 11 | fort saint james
# Processing Record 2 of Set 11 | eldikan
# City not found. Skipping...
# Processing Record 3 of Set 11 | vicosa do ceara
# Processing Record 4 of Set 11 | aden
# Processing Record 5 of Set 11 | novoilinsk
# Processing Record 6 of Set 11 | zemio
# Processing Record 7 of Set 11 | novomykolayivka
# Processing Record 8 of Set 11 | ruatoria
# City not found. Skipping...
# Processing Record 9 of Set 11 | gao
# Processing Record 10 of Set 11 | marawi
# Processing Record 11 of Set 11 | calama
# Processing Record 12 of Set 11 | san fernando
# Processing Record 13 of Set 11 | valer
# Processing Record 14 of Set 11 | flinders
# Processing Record 15 of Set 11 | kamyshlov
# Processing Record 16 of Set 11 | necochea
# Processing Record 17 of Set 11 | yuganets
# Processing Record 18 of Set 11 | chernyshevskiy
# Processing Record 19 of Set 11 | mugur-aksy
# Processing Record 20 of Set 11 | pirgos
# Processing Record 21 of Set 11 | petrozavodsk
# Processing Record 22 of Set 11 | samarai
# Processing Record 23 of Set 11 | zhigansk
# Processing Record 24 of Set 11 | entre rios
# Processing Record 25 of Set 11 | saint-junien
# Processing Record 26 of Set 11 | santa cruz
# Processing Record 27 of Set 11 | taganak
# Processing Record 28 of Set 11 | kralendijk
# Processing Record 29 of Set 11 | murgab
# Processing Record 30 of Set 11 | canico
# Processing Record 31 of Set 11 | umm kaddadah
# Processing Record 32 of Set 11 | port lincoln
# Processing Record 33 of Set 11 | kysyl-syr
# Processing Record 34 of Set 11 | kailua
# Processing Record 35 of Set 11 | egvekinot
# Processing Record 36 of Set 11 | bubaque
# Processing Record 37 of Set 11 | la ronge
# Processing Record 38 of Set 11 | mumford
# Processing Record 39 of Set 11 | shimoda
# Processing Record 40 of Set 11 | lakatoro
# Processing Record 41 of Set 11 | asfi
# Processing Record 42 of Set 11 | gurgan
# City not found. Skipping...
# Processing Record 43 of Set 11 | mahibadhoo
# Processing Record 44 of Set 11 | coihaique
# Processing Record 45 of Set 11 | uige
# Processing Record 46 of Set 11 | praia da vitoria
# Processing Record 47 of Set 11 | formosa
# Processing Record 48 of Set 11 | kuybyshevo
# Processing Record 49 of Set 11 | potsdam
# Processing Record 50 of Set 11 | smithers
# Processing Record 1 of Set 12 | prince rupert
# Processing Record 2 of Set 12 | storm lake
# Processing Record 3 of Set 12 | mutoko
# Processing Record 4 of Set 12 | wagar
# Processing Record 5 of Set 12 | saldanha
# Processing Record 6 of Set 12 | dalneye konstantinovo
# City not found. Skipping...
# Processing Record 7 of Set 12 | nelidovo
# Processing Record 8 of Set 12 | ruidoso
# Processing Record 9 of Set 12 | windsor
# Processing Record 10 of Set 12 | iralaya
# Processing Record 11 of Set 12 | chiang kham
# Processing Record 12 of Set 12 | cheremukhovo
# Processing Record 13 of Set 12 | bardiyah
# Processing Record 14 of Set 12 | krivosheino
# Processing Record 15 of Set 12 | barda
# Processing Record 16 of Set 12 | laurel
# Processing Record 17 of Set 12 | ust-karsk
# Processing Record 18 of Set 12 | cortes
# Processing Record 19 of Set 12 | lagoa vermelha
# Processing Record 20 of Set 12 | severo-yeniseyskiy
# Processing Record 21 of Set 12 | mys shmidta
# City not found. Skipping...
# Processing Record 22 of Set 12 | port hawkesbury
# Processing Record 23 of Set 12 | nouakchott
# Processing Record 24 of Set 12 | mareeba
# Processing Record 25 of Set 12 | avera
# Processing Record 26 of Set 12 | kolimvari
# City not found. Skipping...
# Processing Record 27 of Set 12 | xining
# Processing Record 28 of Set 12 | kalengwa
# Processing Record 29 of Set 12 | sioux lookout
# Processing Record 30 of Set 12 | lady lake
# Processing Record 31 of Set 12 | yasnyy
# Processing Record 32 of Set 12 | piacabucu
# Processing Record 33 of Set 12 | bryan
# Processing Record 34 of Set 12 | kachug
# Processing Record 35 of Set 12 | souris
# Processing Record 36 of Set 12 | atar
# Processing Record 37 of Set 12 | sobolevo
# Processing Record 38 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 39 of Set 12 | bontang
# Processing Record 40 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 41 of Set 12 | plerin
# Processing Record 42 of Set 12 | xichang
# Processing Record 43 of Set 12 | yanchukan
# City not found. Skipping...
# Processing Record 44 of Set 12 | gandai
# Processing Record 45 of Set 12 | kirakira
# Processing Record 46 of Set 12 | santa maria
# Processing Record 47 of Set 12 | gogrial
# Processing Record 48 of Set 12 | nishihara
# Processing Record 49 of Set 12 | videira
# Processing Record 50 of Set 12 | lensk
# Processing Record 1 of Set 13 | kawalu
# Processing Record 2 of Set 13 | mbini
# Processing Record 3 of Set 13 | horadiz
# Processing Record 4 of Set 13 | northam
# Processing Record 5 of Set 13 | las vegas
# Processing Record 6 of Set 13 | sehore
# Processing Record 7 of Set 13 | falciu
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 561

# %% [markdown]
# # Create a DataFrame of City Weather Data

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     Luderitz -26.6481   15.1594     59.68        85           0       11.03
# 1       Hobart -42.8794  147.3294     76.01        43          40        5.99
# 2    Chegdomyn  51.1167  133.0167     17.02        88         100        7.00
# 3     Sisimiut  66.9395  -53.6735     25.74        67         100       36.62
# 4    Busselton -33.6500  115.3333     70.09        42          32       10.74
# 5    Jamestown  42.0970  -79.2353     47.79        69          90       10.00
# 6  Port Alfred -33.5906   26.8910     66.27        91          82       22.19
# 7      Waitara -38.9250  174.2500     70.72        91         100        8.61
# 8      Crofton  39.0018  -76.6875     48.81        77          90        1.01
# 9      Ushuaia -54.8000  -68.3000     44.26        61          20       23.02
#
#   Country                 Date
# 0      NA  2021-12-06 04:26:45
# 1      AU  2021-12-06 04:26:46
# 2      RU  2021-12-06 04:24:17
# 3      GL  2021-12-06 04:26:46
# 4      AU  2021-12-06 04:26:47
# 5      US  2021-12-06 04:26:27
# 6      ZA  2021-12-06 04:26:47
# 7      NZ  2021-12-06 04:26:48
# 8      US  2021-12-06 04:26:48
# 9      AR  2021-12-06 04:26:48

# %%
new_column_order = ["City", "Country", "Date" , "Lat" , "Lng", "Max Temp", "Humidity" , "Cloudiness", "Wind Speed"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(5)
# Out:
#         City Country                 Date      Lat       Lng  Max Temp  \
# 0   Luderitz      NA  2021-12-06 04:26:45 -26.6481   15.1594     59.68
# 1     Hobart      AU  2021-12-06 04:26:46 -42.8794  147.3294     76.01
# 2  Chegdomyn      RU  2021-12-06 04:24:17  51.1167  133.0167     17.02
# 3   Sisimiut      GL  2021-12-06 04:26:46  66.9395  -53.6735     25.74
# 4  Busselton      AU  2021-12-06 04:26:47 -33.6500  115.3333     70.09
#
#    Humidity  Cloudiness  Wind Speed
# 0        85           0       11.03
# 1        43          40        5.99
# 2        88         100        7.00
# 3        67         100       36.62
# 4        42          32       10.74

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

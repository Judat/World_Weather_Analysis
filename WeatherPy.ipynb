# %%
# Import the dependencies.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# !pip install citipy
# Out:
# Requirement already satisfied: citipy in c:\programdata\anaconda3\lib\site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in c:\programdata\anaconda3\lib\site-packages (from citipy) (0.16)

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
# Add thelatitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 600

# %%
# API created

# %%
# The JavaScript Object Notation Format for API Data

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

# Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
    # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
    # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | new norfolk
# Processing Record 2 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 3 of Set 1 | punta arenas
# Processing Record 4 of Set 1 | arraial do cabo
# Processing Record 5 of Set 1 | jamestown
# Processing Record 6 of Set 1 | port elizabeth
# Processing Record 7 of Set 1 | ushuaia
# Processing Record 8 of Set 1 | hilo
# Processing Record 9 of Set 1 | kapaa
# Processing Record 10 of Set 1 | meulaboh
# Processing Record 11 of Set 1 | christchurch
# Processing Record 12 of Set 1 | chernyshevskiy
# Processing Record 13 of Set 1 | tulun
# Processing Record 14 of Set 1 | vaini
# Processing Record 15 of Set 1 | kulhudhuffushi
# Processing Record 16 of Set 1 | puerto ayora
# Processing Record 17 of Set 1 | sola
# Processing Record 18 of Set 1 | ahuimanu
# Processing Record 19 of Set 1 | bluff
# Processing Record 20 of Set 1 | kadnikov
# Processing Record 21 of Set 1 | cape town
# Processing Record 22 of Set 1 | busselton
# Processing Record 23 of Set 1 | olinda
# Processing Record 24 of Set 1 | margate
# Processing Record 25 of Set 1 | tiksi
# Processing Record 26 of Set 1 | bengkulu
# Processing Record 27 of Set 1 | calvinia
# Processing Record 28 of Set 1 | hermanus
# Processing Record 29 of Set 1 | guerrero negro
# Processing Record 30 of Set 1 | sucua
# Processing Record 31 of Set 1 | leningradskiy
# Processing Record 32 of Set 1 | bethel
# Processing Record 33 of Set 1 | bredasdorp
# Processing Record 34 of Set 1 | klaksvik
# Processing Record 35 of Set 1 | mataura
# Processing Record 36 of Set 1 | albany
# Processing Record 37 of Set 1 | novyy oskol
# Processing Record 38 of Set 1 | maridi
# Processing Record 39 of Set 1 | olafsvik
# Processing Record 40 of Set 1 | chipata
# Processing Record 41 of Set 1 | cairns
# Processing Record 42 of Set 1 | nikel
# Processing Record 43 of Set 1 | abu dhabi
# Processing Record 44 of Set 1 | le havre
# Processing Record 45 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 46 of Set 1 | cidreira
# Processing Record 47 of Set 1 | dikson
# Processing Record 48 of Set 1 | upernavik
# Processing Record 49 of Set 1 | mantua
# Processing Record 50 of Set 1 | lasa
# Processing Record 1 of Set 2 | homer
# Processing Record 2 of Set 2 | avera
# Processing Record 3 of Set 2 | east london
# Processing Record 4 of Set 2 | jovellanos
# Processing Record 5 of Set 2 | cabo san lucas
# Processing Record 6 of Set 2 | butaritari
# Processing Record 7 of Set 2 | mount isa
# Processing Record 8 of Set 2 | arlit
# Processing Record 9 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 10 of Set 2 | narsaq
# Processing Record 11 of Set 2 | svetlyy
# Processing Record 12 of Set 2 | carnarvon
# Processing Record 13 of Set 2 | kenora
# Processing Record 14 of Set 2 | atuona
# Processing Record 15 of Set 2 | fortuna
# Processing Record 16 of Set 2 | la tuque
# Processing Record 17 of Set 2 | rongcheng
# Processing Record 18 of Set 2 | severo-kurilsk
# Processing Record 19 of Set 2 | kaitangata
# Processing Record 20 of Set 2 | saint-philippe
# Processing Record 21 of Set 2 | avarua
# Processing Record 22 of Set 2 | rikitea
# Processing Record 23 of Set 2 | kavieng
# Processing Record 24 of Set 2 | xuanhua
# Processing Record 25 of Set 2 | honiara
# Processing Record 26 of Set 2 | qaanaaq
# Processing Record 27 of Set 2 | lucea
# Processing Record 28 of Set 2 | khuzhir
# Processing Record 29 of Set 2 | nanortalik
# Processing Record 30 of Set 2 | tuktoyaktuk
# Processing Record 31 of Set 2 | nalut
# Processing Record 32 of Set 2 | sherman
# Processing Record 33 of Set 2 | katokhi
# City not found. Skipping...
# Processing Record 34 of Set 2 | port alfred
# Processing Record 35 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 36 of Set 2 | bilibino
# Processing Record 37 of Set 2 | tabiauea
# City not found. Skipping...
# Processing Record 38 of Set 2 | pacora
# Processing Record 39 of Set 2 | kaiyuan
# Processing Record 40 of Set 2 | vostok
# Processing Record 41 of Set 2 | sassandra
# Processing Record 42 of Set 2 | flinders
# Processing Record 43 of Set 2 | kamaishi
# Processing Record 44 of Set 2 | lebu
# Processing Record 45 of Set 2 | mar del plata
# Processing Record 46 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 47 of Set 2 | geraldton
# Processing Record 48 of Set 2 | tokur
# Processing Record 49 of Set 2 | saint george
# Processing Record 50 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 1 of Set 3 | karasjok
# Processing Record 2 of Set 3 | bambous virieux
# Processing Record 3 of Set 3 | el cobre
# Processing Record 4 of Set 3 | ancud
# Processing Record 5 of Set 3 | tianpeng
# Processing Record 6 of Set 3 | salamiyah
# Processing Record 7 of Set 3 | biak
# Processing Record 8 of Set 3 | oliveira
# Processing Record 9 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 10 of Set 3 | bulgan
# Processing Record 11 of Set 3 | sedona
# Processing Record 12 of Set 3 | aklavik
# Processing Record 13 of Set 3 | edd
# Processing Record 14 of Set 3 | saskylakh
# Processing Record 15 of Set 3 | newport
# Processing Record 16 of Set 3 | brae
# Processing Record 17 of Set 3 | rungata
# City not found. Skipping...
# Processing Record 18 of Set 3 | louisbourg
# City not found. Skipping...
# Processing Record 19 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 20 of Set 3 | apiai
# Processing Record 21 of Set 3 | yubari
# Processing Record 22 of Set 3 | zhezkazgan
# Processing Record 23 of Set 3 | marinette
# Processing Record 24 of Set 3 | castro
# Processing Record 25 of Set 3 | mullaitivu
# City not found. Skipping...
# Processing Record 26 of Set 3 | dovers
# Processing Record 27 of Set 3 | voyvozh
# Processing Record 28 of Set 3 | general roca
# Processing Record 29 of Set 3 | kiunga
# Processing Record 30 of Set 3 | quiniput
# Processing Record 31 of Set 3 | kirkwall
# Processing Record 32 of Set 3 | chapais
# Processing Record 33 of Set 3 | clyde river
# Processing Record 34 of Set 3 | esna
# Processing Record 35 of Set 3 | olovyannaya
# Processing Record 36 of Set 3 | dingle
# Processing Record 37 of Set 3 | methven
# Processing Record 38 of Set 3 | carutapera
# Processing Record 39 of Set 3 | santa maria
# Processing Record 40 of Set 3 | pelym
# Processing Record 41 of Set 3 | zhangye
# Processing Record 42 of Set 3 | hasaki
# Processing Record 43 of Set 3 | nioki
# Processing Record 44 of Set 3 | nishihara
# Processing Record 45 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 46 of Set 3 | mount gambier
# Processing Record 47 of Set 3 | sao filipe
# Processing Record 48 of Set 3 | auki
# Processing Record 49 of Set 3 | mayuge
# Processing Record 50 of Set 3 | saldanha
# Processing Record 1 of Set 4 | ambulu
# Processing Record 2 of Set 4 | barrow
# Processing Record 3 of Set 4 | perth
# Processing Record 4 of Set 4 | asfi
# Processing Record 5 of Set 4 | bulungu
# Processing Record 6 of Set 4 | rocky mountain house
# Processing Record 7 of Set 4 | ribeira grande
# Processing Record 8 of Set 4 | aflu
# City not found. Skipping...
# Processing Record 9 of Set 4 | huarmey
# Processing Record 10 of Set 4 | bealanana
# Processing Record 11 of Set 4 | nabire
# Processing Record 12 of Set 4 | jalu
# Processing Record 13 of Set 4 | nome
# Processing Record 14 of Set 4 | bezenchuk
# Processing Record 15 of Set 4 | palmer
# Processing Record 16 of Set 4 | grindavik
# Processing Record 17 of Set 4 | dongsheng
# Processing Record 18 of Set 4 | mahebourg
# Processing Record 19 of Set 4 | hua hin
# Processing Record 20 of Set 4 | ust-ilimsk
# Processing Record 21 of Set 4 | airai
# Processing Record 22 of Set 4 | khatanga
# Processing Record 23 of Set 4 | tabialan
# City not found. Skipping...
# Processing Record 24 of Set 4 | veraval
# Processing Record 25 of Set 4 | genhe
# Processing Record 26 of Set 4 | gamba
# Processing Record 27 of Set 4 | guican
# Processing Record 28 of Set 4 | grand baie
# Processing Record 29 of Set 4 | kalmunai
# Processing Record 30 of Set 4 | ponta do sol
# Processing Record 31 of Set 4 | panjab
# Processing Record 32 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 33 of Set 4 | waitati
# Processing Record 34 of Set 4 | naze
# Processing Record 35 of Set 4 | port lincoln
# Processing Record 36 of Set 4 | riberalta
# Processing Record 37 of Set 4 | codrington
# Processing Record 38 of Set 4 | tasiilaq
# Processing Record 39 of Set 4 | hithadhoo
# Processing Record 40 of Set 4 | victoria
# Processing Record 41 of Set 4 | macaboboni
# City not found. Skipping...
# Processing Record 42 of Set 4 | barabash
# Processing Record 43 of Set 4 | yellowknife
# Processing Record 44 of Set 4 | lorengau
# Processing Record 45 of Set 4 | ostrovnoy
# Processing Record 46 of Set 4 | ous
# Processing Record 47 of Set 4 | isangel
# Processing Record 48 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 49 of Set 4 | deputatskiy
# Processing Record 50 of Set 4 | sari
# Processing Record 1 of Set 5 | aripuana
# Processing Record 2 of Set 5 | kolondieba
# Processing Record 3 of Set 5 | ilulissat
# Processing Record 4 of Set 5 | juazeiro
# Processing Record 5 of Set 5 | ginir
# Processing Record 6 of Set 5 | vila
# Processing Record 7 of Set 5 | hamilton
# Processing Record 8 of Set 5 | nikolskoye
# Processing Record 9 of Set 5 | vao
# Processing Record 10 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 11 of Set 5 | norman wells
# Processing Record 12 of Set 5 | malinyi
# Processing Record 13 of Set 5 | waddan
# Processing Record 14 of Set 5 | mrirt
# City not found. Skipping...
# Processing Record 15 of Set 5 | kodiak
# Processing Record 16 of Set 5 | provideniya
# Processing Record 17 of Set 5 | roald
# Processing Record 18 of Set 5 | hobyo
# Processing Record 19 of Set 5 | albion
# Processing Record 20 of Set 5 | kasongo-lunda
# Processing Record 21 of Set 5 | ingleside
# Processing Record 22 of Set 5 | luanda
# Processing Record 23 of Set 5 | alice springs
# Processing Record 24 of Set 5 | dimapur
# Processing Record 25 of Set 5 | kieta
# Processing Record 26 of Set 5 | vestmannaeyjar
# Processing Record 27 of Set 5 | visby
# Processing Record 28 of Set 5 | sobolevo
# Processing Record 29 of Set 5 | rock springs
# Processing Record 30 of Set 5 | taltal
# Processing Record 31 of Set 5 | bathsheba
# Processing Record 32 of Set 5 | morros
# Processing Record 33 of Set 5 | georgetown
# Processing Record 34 of Set 5 | lompoc
# Processing Record 35 of Set 5 | zhigansk
# Processing Record 36 of Set 5 | longyearbyen
# Processing Record 37 of Set 5 | broome
# Processing Record 38 of Set 5 | hovd
# Processing Record 39 of Set 5 | san carlos de bariloche
# Processing Record 40 of Set 5 | skagastrond
# City not found. Skipping...
# Processing Record 41 of Set 5 | north battleford
# Processing Record 42 of Set 5 | bognor regis
# Processing Record 43 of Set 5 | praia
# Processing Record 44 of Set 5 | beringovskiy
# Processing Record 45 of Set 5 | khuzdar
# Processing Record 46 of Set 5 | riyadh
# Processing Record 47 of Set 5 | faanui
# Processing Record 48 of Set 5 | thinadhoo
# Processing Record 49 of Set 5 | saint-pierre
# Processing Record 50 of Set 5 | sika
# Processing Record 1 of Set 6 | peniche
# Processing Record 2 of Set 6 | loandjili
# Processing Record 3 of Set 6 | varhaug
# Processing Record 4 of Set 6 | buraydah
# Processing Record 5 of Set 6 | tayibe
# City not found. Skipping...
# Processing Record 6 of Set 6 | vila velha
# Processing Record 7 of Set 6 | fort saint john
# City not found. Skipping...
# Processing Record 8 of Set 6 | zabol
# Processing Record 9 of Set 6 | ilebo
# Processing Record 10 of Set 6 | te anau
# Processing Record 11 of Set 6 | marsa matruh
# Processing Record 12 of Set 6 | pimenta bueno
# Processing Record 13 of Set 6 | mathbaria
# Processing Record 14 of Set 6 | hervey bay
# Processing Record 15 of Set 6 | tombouctou
# Processing Record 16 of Set 6 | yunhe
# Processing Record 17 of Set 6 | andenes
# Processing Record 18 of Set 6 | chitral
# Processing Record 19 of Set 6 | souillac
# Processing Record 20 of Set 6 | morehead
# Processing Record 21 of Set 6 | zachagansk
# City not found. Skipping...
# Processing Record 22 of Set 6 | safaga
# Processing Record 23 of Set 6 | hobart
# Processing Record 24 of Set 6 | luena
# Processing Record 25 of Set 6 | beidao
# Processing Record 26 of Set 6 | touros
# Processing Record 27 of Set 6 | voznesenye
# Processing Record 28 of Set 6 | fairbanks
# Processing Record 29 of Set 6 | thompson
# Processing Record 30 of Set 6 | iznoski
# Processing Record 31 of Set 6 | yar-sale
# Processing Record 32 of Set 6 | awbari
# Processing Record 33 of Set 6 | salou
# Processing Record 34 of Set 6 | pevek
# Processing Record 35 of Set 6 | victor harbor
# Processing Record 36 of Set 6 | sao joao da barra
# Processing Record 37 of Set 6 | kuching
# Processing Record 38 of Set 6 | panambi
# Processing Record 39 of Set 6 | kemijarvi
# Processing Record 40 of Set 6 | burnie
# Processing Record 41 of Set 6 | masterton
# Processing Record 42 of Set 6 | altamira
# Processing Record 43 of Set 6 | dunedin
# Processing Record 44 of Set 6 | florianopolis
# Processing Record 45 of Set 6 | khani
# Processing Record 46 of Set 6 | kendallville
# Processing Record 47 of Set 6 | svetlogorsk
# Processing Record 48 of Set 6 | dombarovskiy
# Processing Record 49 of Set 6 | luderitz
# Processing Record 50 of Set 6 | karaul
# City not found. Skipping...
# Processing Record 1 of Set 7 | esperance
# Processing Record 2 of Set 7 | ust-kulom
# Processing Record 3 of Set 7 | sorong
# Processing Record 4 of Set 7 | itigi
# Processing Record 5 of Set 7 | pochutla
# Processing Record 6 of Set 7 | oga
# Processing Record 7 of Set 7 | bonavista
# Processing Record 8 of Set 7 | nelson bay
# Processing Record 9 of Set 7 | erenhot
# Processing Record 10 of Set 7 | chuy
# Processing Record 11 of Set 7 | sioux lookout
# Processing Record 12 of Set 7 | vermillion
# Processing Record 13 of Set 7 | lamu
# Processing Record 14 of Set 7 | carai
# Processing Record 15 of Set 7 | chato
# Processing Record 16 of Set 7 | pangai
# Processing Record 17 of Set 7 | cayenne
# Processing Record 18 of Set 7 | madhupur
# Processing Record 19 of Set 7 | aleysk
# Processing Record 20 of Set 7 | westport
# Processing Record 21 of Set 7 | onega
# Processing Record 22 of Set 7 | brigantine
# Processing Record 23 of Set 7 | tiznit
# Processing Record 24 of Set 7 | heinola
# Processing Record 25 of Set 7 | illapel
# Processing Record 26 of Set 7 | bartica
# Processing Record 27 of Set 7 | khormuj
# City not found. Skipping...
# Processing Record 28 of Set 7 | nha trang
# Processing Record 29 of Set 7 | iqaluit
# Processing Record 30 of Set 7 | la ronge
# Processing Record 31 of Set 7 | mbandaka
# Processing Record 32 of Set 7 | kuche
# City not found. Skipping...
# Processing Record 33 of Set 7 | verkh-usugli
# Processing Record 34 of Set 7 | makakilo city
# Processing Record 35 of Set 7 | batsfjord
# Processing Record 36 of Set 7 | urucara
# Processing Record 37 of Set 7 | kushmurun
# Processing Record 38 of Set 7 | aras
# Processing Record 39 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 40 of Set 7 | chokurdakh
# Processing Record 41 of Set 7 | tuatapere
# Processing Record 42 of Set 7 | teya
# Processing Record 43 of Set 7 | simpang
# Processing Record 44 of Set 7 | kegayli
# City not found. Skipping...
# Processing Record 45 of Set 7 | krasnoselkup
# Processing Record 46 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 47 of Set 7 | yenagoa
# Processing Record 48 of Set 7 | portland
# Processing Record 49 of Set 7 | warri
# Processing Record 50 of Set 7 | kodinsk
# Processing Record 1 of Set 8 | dakar
# Processing Record 2 of Set 8 | minas
# Processing Record 3 of Set 8 | pilar
# Processing Record 4 of Set 8 | namibe
# Processing Record 5 of Set 8 | lukovetskiy
# Processing Record 6 of Set 8 | petropavlovskoye
# Processing Record 7 of Set 8 | katangli
# Processing Record 8 of Set 8 | polyarnyy
# Processing Record 9 of Set 8 | rio grande
# Processing Record 10 of Set 8 | raudeberg
# Processing Record 11 of Set 8 | talnakh
# Processing Record 12 of Set 8 | marystown
# Processing Record 13 of Set 8 | sakakah
# Processing Record 14 of Set 8 | kaabong
# Processing Record 15 of Set 8 | bubaque
# Processing Record 16 of Set 8 | mareeba
# Processing Record 17 of Set 8 | cabedelo
# Processing Record 18 of Set 8 | kandrian
# Processing Record 19 of Set 8 | san andres
# Processing Record 20 of Set 8 | gull lake
# Processing Record 21 of Set 8 | amot
# Processing Record 22 of Set 8 | arica
# Processing Record 23 of Set 8 | ondorhaan
# City not found. Skipping...
# Processing Record 24 of Set 8 | floro
# Processing Record 25 of Set 8 | jagdispur
# Processing Record 26 of Set 8 | college
# Processing Record 27 of Set 8 | manzanillo
# Processing Record 28 of Set 8 | viedma
# Processing Record 29 of Set 8 | kisangani
# Processing Record 30 of Set 8 | metepec
# Processing Record 31 of Set 8 | marawi
# Processing Record 32 of Set 8 | hambantota
# Processing Record 33 of Set 8 | adrar
# Processing Record 34 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 35 of Set 8 | uwayl
# City not found. Skipping...
# Processing Record 36 of Set 8 | lindi
# Processing Record 37 of Set 8 | guia de isora
# Processing Record 38 of Set 8 | tuensang
# Processing Record 39 of Set 8 | arandis
# Processing Record 40 of Set 8 | lavrentiya
# Processing Record 41 of Set 8 | puerto ayacucho
# Processing Record 42 of Set 8 | yumen
# Processing Record 43 of Set 8 | plaridel
# Processing Record 44 of Set 8 | korla
# Processing Record 45 of Set 8 | quatre cocos
# Processing Record 46 of Set 8 | pimentel
# Processing Record 47 of Set 8 | ambilobe
# Processing Record 48 of Set 8 | qui nhon
# Processing Record 49 of Set 8 | tual
# Processing Record 50 of Set 8 | bargal
# City not found. Skipping...
# Processing Record 1 of Set 9 | los llanos de aridane
# Processing Record 2 of Set 9 | tanabe
# Processing Record 3 of Set 9 | phan thiet
# Processing Record 4 of Set 9 | dunkwa
# Processing Record 5 of Set 9 | chaska
# Processing Record 6 of Set 9 | katsuura
# Processing Record 7 of Set 9 | tura
# Processing Record 8 of Set 9 | kajaani
# Processing Record 9 of Set 9 | sao gabriel da cachoeira
# Processing Record 10 of Set 9 | outram
# Processing Record 11 of Set 9 | kailua
# Processing Record 12 of Set 9 | kimbe
# Processing Record 13 of Set 9 | novokruchininskiy
# Processing Record 14 of Set 9 | rawson
# Processing Record 15 of Set 9 | kedrovyy
# Processing Record 16 of Set 9 | whitehorse
# Processing Record 17 of Set 9 | ola
# Processing Record 18 of Set 9 | tahta
# Processing Record 19 of Set 9 | araouane
# Processing Record 20 of Set 9 | vardo
# Processing Record 21 of Set 9 | garden city
# Processing Record 22 of Set 9 | henties bay
# Processing Record 23 of Set 9 | inuvik
# Processing Record 24 of Set 9 | shizilu
# Processing Record 25 of Set 9 | saravan
# Processing Record 26 of Set 9 | mishelevka
# Processing Record 27 of Set 9 | santiago del estero
# Processing Record 28 of Set 9 | acapulco
# Processing Record 29 of Set 9 | drayton valley
# Processing Record 30 of Set 9 | salinas
# Processing Record 31 of Set 9 | alofi
# Processing Record 32 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 33 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 34 of Set 9 | bonthe
# Processing Record 35 of Set 9 | tambo
# Processing Record 36 of Set 9 | papar
# Processing Record 37 of Set 9 | saint-francois
# Processing Record 38 of Set 9 | tautira
# Processing Record 39 of Set 9 | matara
# Processing Record 40 of Set 9 | lagoa
# Processing Record 41 of Set 9 | san angelo
# Processing Record 42 of Set 9 | morgan city
# Processing Record 43 of Set 9 | quelimane
# Processing Record 44 of Set 9 | mafinga
# Processing Record 45 of Set 9 | pisco
# Processing Record 46 of Set 9 | salalah
# Processing Record 47 of Set 9 | san patricio
# Processing Record 48 of Set 9 | opuwo
# Processing Record 49 of Set 9 | sorland
# Processing Record 50 of Set 9 | fandriana
# Processing Record 1 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 2 of Set 10 | ossora
# Processing Record 3 of Set 10 | port macquarie
# Processing Record 4 of Set 10 | ronne
# Processing Record 5 of Set 10 | konigslutter
# City not found. Skipping...
# Processing Record 6 of Set 10 | nantucket
# Processing Record 7 of Set 10 | khorixas
# Processing Record 8 of Set 10 | hualmay
# Processing Record 9 of Set 10 | charters towers
# Processing Record 10 of Set 10 | vikhorevka
# Processing Record 11 of Set 10 | aksu
# Processing Record 12 of Set 10 | tilichiki
# Processing Record 13 of Set 10 | lagunas
# Processing Record 14 of Set 10 | warrenville
# Processing Record 15 of Set 10 | champerico
# Processing Record 16 of Set 10 | diplo
# Processing Record 17 of Set 10 | sala
# Processing Record 18 of Set 10 | laguna
# Processing Record 19 of Set 10 | akcakoca
# Processing Record 20 of Set 10 | misratah
# Processing Record 21 of Set 10 | basco
# Processing Record 22 of Set 10 | sabya
# Processing Record 23 of Set 10 | belyy yar
# Processing Record 24 of Set 10 | ascension
# Processing Record 25 of Set 10 | ashington
# Processing Record 26 of Set 10 | dieppe bay
# City not found. Skipping...
# Processing Record 27 of Set 10 | baykit
# Processing Record 28 of Set 10 | padang
# Processing Record 29 of Set 10 | half moon bay
# Processing Record 30 of Set 10 | henzada
# City not found. Skipping...
# Processing Record 31 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 32 of Set 10 | nemuro
# Processing Record 33 of Set 10 | aykhal
# Processing Record 34 of Set 10 | ipira
# Processing Record 35 of Set 10 | mogadishu
# Processing Record 36 of Set 10 | erzin
# Processing Record 37 of Set 10 | tarudant
# City not found. Skipping...
# Processing Record 38 of Set 10 | palauig
# Processing Record 39 of Set 10 | rovaniemi
# Processing Record 40 of Set 10 | tomaszow lubelski
# Processing Record 41 of Set 10 | dawei
# Processing Record 42 of Set 10 | algodones
# Processing Record 43 of Set 10 | chagda
# City not found. Skipping...
# Processing Record 44 of Set 10 | bressanone
# Processing Record 45 of Set 10 | panaba
# Processing Record 46 of Set 10 | demba
# Processing Record 47 of Set 10 | puyang
# Processing Record 48 of Set 10 | nueve de julio
# Processing Record 49 of Set 10 | oranjemund
# Processing Record 50 of Set 10 | meadow lake
# Processing Record 1 of Set 11 | ilam
# Processing Record 2 of Set 11 | buarcos
# Processing Record 3 of Set 11 | cherskiy
# Processing Record 4 of Set 11 | ust-kuyga
# Processing Record 5 of Set 11 | solnechnyy
# Processing Record 6 of Set 11 | kalomo
# City not found. Skipping...
# Processing Record 7 of Set 11 | eidsvag
# Processing Record 8 of Set 11 | bacuit
# City not found. Skipping...
# Processing Record 9 of Set 11 | gualaquiza
# Processing Record 10 of Set 11 | sinnamary
# Processing Record 11 of Set 11 | san policarpo
# Processing Record 12 of Set 11 | tingrela
# City not found. Skipping...
# Processing Record 13 of Set 11 | caravelas
# Processing Record 14 of Set 11 | abu kamal
# Processing Record 15 of Set 11 | micheweni
# Processing Record 16 of Set 11 | sao desiderio
# Processing Record 17 of Set 11 | carthage
# Processing Record 18 of Set 11 | keti bandar
# Processing Record 19 of Set 11 | sheltozero
# Processing Record 20 of Set 11 | cockburn town
# Processing Record 21 of Set 11 | gondar
# Processing Record 22 of Set 11 | ucluelet
# Processing Record 23 of Set 11 | montepuez
# Processing Record 24 of Set 11 | lisala
# Processing Record 25 of Set 11 | concepcion del uruguay
# Processing Record 26 of Set 11 | vysokaya gora
# Processing Record 27 of Set 11 | taua
# Processing Record 28 of Set 11 | kokopo
# Processing Record 29 of Set 11 | chingirlau
# Processing Record 30 of Set 11 | balaka
# Processing Record 31 of Set 11 | koulikoro
# Processing Record 32 of Set 11 | odesskoye
# Processing Record 33 of Set 11 | constitucion
# Processing Record 34 of Set 11 | chenzhou
# Processing Record 35 of Set 11 | hartselle
# Processing Record 36 of Set 11 | taksimo
# Processing Record 37 of Set 11 | san fernando
# Processing Record 38 of Set 11 | puno
# Processing Record 39 of Set 11 | carupano
# Processing Record 40 of Set 11 | sur
# Processing Record 41 of Set 11 | camacha
# Processing Record 42 of Set 11 | leh
# Processing Record 43 of Set 11 | nepalganj
# City not found. Skipping...
# Processing Record 44 of Set 11 | solovetskiy
# City not found. Skipping...
# Processing Record 45 of Set 11 | svetlaya
# Processing Record 46 of Set 11 | hirara
# Processing Record 47 of Set 11 | eureka
# Processing Record 48 of Set 11 | ituni
# City not found. Skipping...
# Processing Record 49 of Set 11 | iki-burul
# Processing Record 50 of Set 11 | bone
# Processing Record 1 of Set 12 | southern pines
# Processing Record 2 of Set 12 | srivaikuntam
# Processing Record 3 of Set 12 | dicabisagan
# Processing Record 4 of Set 12 | saiha
# Processing Record 5 of Set 12 | chibuto
# Processing Record 6 of Set 12 | sao joao do piaui
# Processing Record 7 of Set 12 | krasnoborsk
# Processing Record 8 of Set 12 | coihaique
# Processing Record 9 of Set 12 | zhukovo
# Processing Record 10 of Set 12 | hammerfest
# Processing Record 11 of Set 12 | fort nelson
# Processing Record 12 of Set 12 | muros
# Processing Record 13 of Set 12 | sucha beskidzka
# Processing Record 14 of Set 12 | malakal
# Processing Record 15 of Set 12 | ajdabiya
# Processing Record 16 of Set 12 | lata
# Processing Record 17 of Set 12 | smithers
# Processing Record 18 of Set 12 | tuburan
# Processing Record 19 of Set 12 | gat
# Processing Record 20 of Set 12 | prince albert
# Processing Record 21 of Set 12 | dwarka
# Processing Record 22 of Set 12 | puerto del rosario
# Processing Record 23 of Set 12 | north bend
# Processing Record 24 of Set 12 | zemio
# Processing Record 25 of Set 12 | prattville
# Processing Record 26 of Set 12 | omboue
# Processing Record 27 of Set 12 | ketchikan
# Processing Record 28 of Set 12 | amurzet
# Processing Record 29 of Set 12 | rosa
# Processing Record 30 of Set 12 | les escoumins
# Processing Record 31 of Set 12 | popondetta
# Processing Record 32 of Set 12 | vaitape
# Processing Record 33 of Set 12 | bandarbeyla
# Processing Record 34 of Set 12 | paradwip
# City not found. Skipping...
# Processing Record 35 of Set 12 | porto nacional
# Processing Record 36 of Set 12 | oriximina
# Processing Record 37 of Set 12 | wulanhaote
# City not found. Skipping...
# Processing Record 38 of Set 12 | mana
# Processing Record 39 of Set 12 | yerbogachen
# Processing Record 40 of Set 12 | jackson
# Processing Record 41 of Set 12 | niono
# Processing Record 42 of Set 12 | tidore
# City not found. Skipping...
# Processing Record 43 of Set 12 | okha
# Processing Record 44 of Set 12 | sault sainte marie
# Processing Record 45 of Set 12 | puerto escondido
# Processing Record 46 of Set 12 | beian
# Processing Record 47 of Set 12 | necochea
# Processing Record 48 of Set 12 | santa isabel do rio negro
# Processing Record 49 of Set 12 | bayshore gardens
# Processing Record 50 of Set 12 | taoudenni
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 548

# %% [markdown]
# # Create a DataFrame of City Weather Data

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      New Norfolk -42.7826  147.0587     58.71        52          71
# 1     Punta Arenas -53.1500  -70.9167     50.11        50          20
# 2  Arraial Do Cabo -22.9661  -42.0278     72.36        80          99
# 3        Jamestown  42.0970  -79.2353     29.52        88          40
# 4   Port Elizabeth -33.9180   25.5701     64.69        82          75
# 5          Ushuaia -54.8000  -68.3000     46.06        53          40
# 6             Hilo  19.7297 -155.0900     80.33        40          90
# 7            Kapaa  22.0752 -159.3190     82.38        78          20
# 8         Meulaboh   4.1363   96.1285     76.35        86          13
# 9     Christchurch -43.5333  172.6333     66.33        69          20
#
#    Wind Speed Country                 Date
# 0        3.00      AU  2021-12-07 22:39:23
# 1       27.63      CL  2021-12-07 22:39:24
# 2       12.12      BR  2021-12-07 22:39:24
# 3        8.99      US  2021-12-07 22:34:51
# 4        3.44      ZA  2021-12-07 22:39:24
# 5       23.02      AR  2021-12-07 22:39:25
# 6       14.97      US  2021-12-07 22:35:48
# 7        1.99      US  2021-12-07 22:39:25
# 8        3.67      ID  2021-12-07 22:39:25
# 9        8.01      NZ  2021-12-07 22:39:26

# %%
new_column_order = ["City", "Country", "Date" , "Lat" , "Lng", "Max Temp", "Humidity" , "Cloudiness", "Wind Speed"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(5)
# Out:
#               City Country                 Date      Lat       Lng  Max Temp  \
# 0      New Norfolk      AU  2021-12-07 22:39:23 -42.7826  147.0587     58.71
# 1     Punta Arenas      CL  2021-12-07 22:39:24 -53.1500  -70.9167     50.11
# 2  Arraial Do Cabo      BR  2021-12-07 22:39:24 -22.9661  -42.0278     72.36
# 3        Jamestown      US  2021-12-07 22:34:51  42.0970  -79.2353     29.52
# 4   Port Elizabeth      ZA  2021-12-07 22:39:24 -33.9180   25.5701     64.69
#
#    Humidity  Cloudiness  Wind Speed
# 0        52          71        3.00
# 1        50          20       27.63
# 2        80          99       12.12
# 3        88          40        8.99
# 4        82          75        3.44

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %% [markdown]
# # Plot Latitude vs. Temperature

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

from datetime import datetime
# Import the time module.
import time
# Get today's date in seconds.
today = time.time()
today
# Out:
# 1638917598.7889454

# %%
today = time.strftime('%x')

# %%
today
# Out:
# '12/07/21'

# %%
# Import time module
import time

# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
            max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)
plt.legend()
# Save the figure.
plt.savefig("weather_data/Latitude vs Max Temperature.png")

# Show plot.
plt.show()

# %% [markdown]
# # Plot Latitude vs. Humidity

# %%
# Import time module
import time

# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity % ")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Latitude vs Humidity.png")

# Show plot.
plt.show()

# %% [markdown]
# # Plot Latitude vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness.
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Latitude vs Cloudiness.png")
# Show plot.
plt.show()

# %% [markdown]
# # Plot Latitude vs. Wind Speed

# %%
# Build the scatter plots for latitude vs. wind speed.
plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Laatitude vs Wind Speed.png")
# Show plot.
plt.show()

# %% [markdown]
# # Create a Linear Regression Function

# %% [markdown]
# ##### Create a function, "plot_linear_regression", and add the four parameters inside the parentheses. Our function should look like the following.

# %%
# Import linregress
from scipy.stats import linregress

# Create a function to create perform linear regression on the weather data
# and plot a regression line and the equation with the data.
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):

    # Run regression on hemisphere weather data.
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)

    # Calculate the regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept
    # Get the equation of the line.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    # Create a scatter plot and plot the regression line.
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r")
    # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.title(title)
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.show()

# %% [markdown]
# # Create the Hemisphere DataFrames to get the parameters for the function

# %%
# Create Northern and Southern Hemisphere DataFrames.
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]
northern_hemi_df.head()
# Out:
#               City Country                 Date      Lat       Lng  Max Temp  \
# 3        Jamestown      US  2021-12-07 22:34:51  42.0970  -79.2353     29.52
# 6             Hilo      US  2021-12-07 22:35:48  19.7297 -155.0900     80.33
# 7            Kapaa      US  2021-12-07 22:39:25  22.0752 -159.3190     82.38
# 8         Meulaboh      ID  2021-12-07 22:39:25   4.1363   96.1285     76.35
# 10  Chernyshevskiy      RU  2021-12-07 22:39:26  63.0128  112.4714    -26.64
#
#     Humidity  Cloudiness  Wind Speed
# 3         88          40        8.99
# 6         40          90       14.97
# 7         78          20        1.99
# 8         86          13        3.67
# 10       100          91        0.76

# %% [markdown]
# # Perform Linear Regression on the Maximum Temperature for the Northern Hemisphere

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
# Call the function.
# def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for Maximum Temperature', 'Max Temp',(10,10))
(slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)
print(f"The slope is: {slope:.3f}")
print(f"The r_value is :{r_value:.3f}")
# Out:
# The slope is: -1.293
# The r_value is :-0.875

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for Maximum Temperature', 'Max Temp',(-50,80))
(slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)
print(f"The slope is: {slope:.3f}")
print(f"The r_value is :{r_value:.3f}")
# Out:
# The slope is: 0.306
# The r_value is :0.471

# %% [markdown]
# # Find the Correlation Between Latitude and Percent Humidity

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for % Humidity', '% Humidity',(40,10))
(slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)
print(f"The slope is: {slope:.3f}")
print(f"The r_value is :{r_value:.3f}")
# Out:
# The slope is: 0.295
# The r_value is :0.291

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for % Humidity', '% Humidity',(-50,30))
(slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)
print(f"The slope is: {slope:.3f}")
print(f"The r_value is :{r_value:.3f}")
# Out:
# The slope is: 0.629
# The r_value is :0.505

# %% [markdown]
# # Find the Correlation Between Latitude and Cloudiness

# %% [markdown]
# ## Perform Linear Regression on the Cloudiness for the Northern Hemisphere

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for Cloudiness', '  Cloudiness',(40,10))
(slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)
print(f"The slope is: {slope:.3f}")
print(f"The r_value is :{r_value:.3f}")
# Out:
# The slope is: 0.334
# The r_value is :0.178

# %% [markdown]
# ## Perform Linear Regression on the Cloudiness for the Southern Hemisphere## Perform Linear Regression on the Cloudiness for the Southern Hemisphere

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for Cloudiness', ' Cloudiness',(-50,15))
(slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)
print(f"The slope is: {slope:.3f}")
print(f"The r_value is :{r_value:.3f}")
# Out:
# The slope is: 0.781
# The r_value is :0.307

# %% [markdown]
# # Find the Correlation Between Latitude and Percent Wind Speed

# %% [markdown]
# ## Perform Linear Regression on the Wind Speed for the Northern Hemisphere

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for Wind Speed', 'Wind Speed',(40,35))
(slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)
print(f"The slope is: {slope:.3f}")
print(f"The r_value is :{r_value:.3f}")
# Out:
# The slope is: 0.032
# The r_value is :0.092

# %% [markdown]
# ## Perform Linear Regression on the Wind Speed for the Southern Hemisphere

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for Wind Speed', 'Wind Speed',(-50,35))
(slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)
print(f"The slope is: {slope:.3f}")
print(f"The r_value is :{r_value:.3f}")
# Out:
# The slope is: -0.155
# The r_value is :-0.377

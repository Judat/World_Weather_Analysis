# %%
# Import the dependencies.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# !pip install citipy
# Out:
# Requirement already satisfied: citipy in c:\programdata\anaconda3\lib\site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in c:\programdata\anaconda3\lib\site-packages (from citipy) (0.16)

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
# Add thelatitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 776

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime
# Create an empty list to hold the weather data.
city_data = []

# %%
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

# Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
    # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
    # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Description" : city_description                          
                          })

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hobyo
# Processing Record 2 of Set 1 | bredasdorp
# Processing Record 3 of Set 1 | tual
# Processing Record 4 of Set 1 | norman wells
# Processing Record 5 of Set 1 | tuktoyaktuk
# Processing Record 6 of Set 1 | dikson
# Processing Record 7 of Set 1 | ushuaia
# Processing Record 8 of Set 1 | albany
# Processing Record 9 of Set 1 | henties bay
# Processing Record 10 of Set 1 | port elizabeth
# Processing Record 11 of Set 1 | talnakh
# Processing Record 12 of Set 1 | port alfred
# Processing Record 13 of Set 1 | rikitea
# Processing Record 14 of Set 1 | ballina
# Processing Record 15 of Set 1 | kindu
# Processing Record 16 of Set 1 | hermanus
# Processing Record 17 of Set 1 | flin flon
# Processing Record 18 of Set 1 | bilibino
# Processing Record 19 of Set 1 | kapaa
# Processing Record 20 of Set 1 | curuca
# Processing Record 21 of Set 1 | mataura
# Processing Record 22 of Set 1 | torbay
# Processing Record 23 of Set 1 | shanghai
# Processing Record 24 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 25 of Set 1 | lafiagi
# Processing Record 26 of Set 1 | arraial do cabo
# Processing Record 27 of Set 1 | punta arenas
# Processing Record 28 of Set 1 | qaanaaq
# Processing Record 29 of Set 1 | hvolsvollur
# Processing Record 30 of Set 1 | isangel
# Processing Record 31 of Set 1 | forestville
# Processing Record 32 of Set 1 | cape town
# Processing Record 33 of Set 1 | oranjestad
# Processing Record 34 of Set 1 | mount gambier
# Processing Record 35 of Set 1 | chifeng
# Processing Record 36 of Set 1 | comodoro rivadavia
# Processing Record 37 of Set 1 | hilo
# Processing Record 38 of Set 1 | palaiokhora
# City not found. Skipping...
# Processing Record 39 of Set 1 | hambantota
# Processing Record 40 of Set 1 | vaini
# Processing Record 41 of Set 1 | sorvag
# City not found. Skipping...
# Processing Record 42 of Set 1 | severo-yeniseyskiy
# Processing Record 43 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 44 of Set 1 | mareeba
# Processing Record 45 of Set 1 | nelson bay
# Processing Record 46 of Set 1 | yellowknife
# Processing Record 47 of Set 1 | abu dhabi
# Processing Record 48 of Set 1 | rumonge
# Processing Record 49 of Set 1 | butaritari
# Processing Record 50 of Set 1 | soe
# Processing Record 1 of Set 2 | vao
# Processing Record 2 of Set 2 | jacksonville
# Processing Record 3 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 4 of Set 2 | guarapari
# Processing Record 5 of Set 2 | burnie
# Processing Record 6 of Set 2 | carutapera
# Processing Record 7 of Set 2 | statesboro
# Processing Record 8 of Set 2 | bengkulu
# Processing Record 9 of Set 2 | atuona
# Processing Record 10 of Set 2 | fort-shevchenko
# Processing Record 11 of Set 2 | urucara
# Processing Record 12 of Set 2 | puerto ayora
# Processing Record 13 of Set 2 | busselton
# Processing Record 14 of Set 2 | chapada dos guimaraes
# Processing Record 15 of Set 2 | hofn
# Processing Record 16 of Set 2 | kalabo
# Processing Record 17 of Set 2 | half moon bay
# Processing Record 18 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 19 of Set 2 | severo-kurilsk
# Processing Record 20 of Set 2 | marzuq
# Processing Record 21 of Set 2 | paamiut
# Processing Record 22 of Set 2 | manjacaze
# Processing Record 23 of Set 2 | auki
# Processing Record 24 of Set 2 | ginir
# Processing Record 25 of Set 2 | maputo
# Processing Record 26 of Set 2 | ayr
# Processing Record 27 of Set 2 | leningradskiy
# Processing Record 28 of Set 2 | provideniya
# Processing Record 29 of Set 2 | pevek
# Processing Record 30 of Set 2 | canora
# Processing Record 31 of Set 2 | mecca
# Processing Record 32 of Set 2 | sur
# Processing Record 33 of Set 2 | gazojak
# Processing Record 34 of Set 2 | jamestown
# Processing Record 35 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 36 of Set 2 | victoria
# Processing Record 37 of Set 2 | jiayuguan
# Processing Record 38 of Set 2 | babati
# Processing Record 39 of Set 2 | shingu
# Processing Record 40 of Set 2 | dingle
# Processing Record 41 of Set 2 | senanga
# Processing Record 42 of Set 2 | katangli
# Processing Record 43 of Set 2 | innisfail
# Processing Record 44 of Set 2 | kodiak
# Processing Record 45 of Set 2 | uige
# Processing Record 46 of Set 2 | saint-philippe
# Processing Record 47 of Set 2 | bluff
# Processing Record 48 of Set 2 | zachary
# Processing Record 49 of Set 2 | puerto varas
# Processing Record 50 of Set 2 | upernavik
# Processing Record 1 of Set 3 | camana
# Processing Record 2 of Set 3 | cuneo
# Processing Record 3 of Set 3 | avarua
# Processing Record 4 of Set 3 | broken hill
# Processing Record 5 of Set 3 | hamilton
# Processing Record 6 of Set 3 | salalah
# Processing Record 7 of Set 3 | tasiilaq
# Processing Record 8 of Set 3 | dunedin
# Processing Record 9 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 10 of Set 3 | ngunguru
# Processing Record 11 of Set 3 | aswan
# Processing Record 12 of Set 3 | luderitz
# Processing Record 13 of Set 3 | estelle
# Processing Record 14 of Set 3 | ilulissat
# Processing Record 15 of Set 3 | mullingar
# Processing Record 16 of Set 3 | qaqortoq
# Processing Record 17 of Set 3 | baillif
# Processing Record 18 of Set 3 | kragujevac
# Processing Record 19 of Set 3 | srednekolymsk
# Processing Record 20 of Set 3 | narsaq
# Processing Record 21 of Set 3 | bubaque
# Processing Record 22 of Set 3 | kavaratti
# Processing Record 23 of Set 3 | san quintin
# Processing Record 24 of Set 3 | pakokku
# Processing Record 25 of Set 3 | kabwe
# Processing Record 26 of Set 3 | tasbuget
# City not found. Skipping...
# Processing Record 27 of Set 3 | sao francisco de assis
# Processing Record 28 of Set 3 | longyearbyen
# Processing Record 29 of Set 3 | kahului
# Processing Record 30 of Set 3 | saint george
# Processing Record 31 of Set 3 | lithgow
# Processing Record 32 of Set 3 | herbrechtingen
# Processing Record 33 of Set 3 | mar del plata
# Processing Record 34 of Set 3 | nikolskoye
# Processing Record 35 of Set 3 | lavrentiya
# Processing Record 36 of Set 3 | buraydah
# Processing Record 37 of Set 3 | rehoboth
# Processing Record 38 of Set 3 | sioux lookout
# Processing Record 39 of Set 3 | hithadhoo
# Processing Record 40 of Set 3 | goderich
# Processing Record 41 of Set 3 | pocoes
# Processing Record 42 of Set 3 | lodwar
# Processing Record 43 of Set 3 | sao filipe
# Processing Record 44 of Set 3 | nosy varika
# Processing Record 45 of Set 3 | touho
# Processing Record 46 of Set 3 | rocky mountain house
# Processing Record 47 of Set 3 | kemijarvi
# Processing Record 48 of Set 3 | luau
# Processing Record 49 of Set 3 | mbamba
# Processing Record 50 of Set 3 | balkanabat
# Processing Record 1 of Set 4 | cherskiy
# Processing Record 2 of Set 4 | lang son
# Processing Record 3 of Set 4 | khartoum
# Processing Record 4 of Set 4 | quelimane
# Processing Record 5 of Set 4 | ocampo
# Processing Record 6 of Set 4 | oistins
# Processing Record 7 of Set 4 | muscat
# Processing Record 8 of Set 4 | hobart
# Processing Record 9 of Set 4 | pokrovskoye
# Processing Record 10 of Set 4 | kasongo-lunda
# Processing Record 11 of Set 4 | rolim de moura
# City not found. Skipping...
# Processing Record 12 of Set 4 | clyde river
# Processing Record 13 of Set 4 | moerai
# Processing Record 14 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 15 of Set 4 | merauke
# Processing Record 16 of Set 4 | kattivakkam
# Processing Record 17 of Set 4 | new norfolk
# Processing Record 18 of Set 4 | halmstad
# Processing Record 19 of Set 4 | xichang
# Processing Record 20 of Set 4 | anar darreh
# City not found. Skipping...
# Processing Record 21 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 22 of Set 4 | gizo
# Processing Record 23 of Set 4 | chizhou
# Processing Record 24 of Set 4 | san cristobal
# Processing Record 25 of Set 4 | san policarpo
# Processing Record 26 of Set 4 | jining
# Processing Record 27 of Set 4 | thompson
# Processing Record 28 of Set 4 | caravelas
# Processing Record 29 of Set 4 | kualakapuas
# Processing Record 30 of Set 4 | khuzhir
# Processing Record 31 of Set 4 | moisei
# Processing Record 32 of Set 4 | udachnyy
# Processing Record 33 of Set 4 | minot
# Processing Record 34 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 35 of Set 4 | ayan
# Processing Record 36 of Set 4 | rocha
# Processing Record 37 of Set 4 | avera
# Processing Record 38 of Set 4 | kamyshin
# Processing Record 39 of Set 4 | bagdarin
# Processing Record 40 of Set 4 | mehamn
# Processing Record 41 of Set 4 | the valley
# Processing Record 42 of Set 4 | daru
# Processing Record 43 of Set 4 | alofi
# Processing Record 44 of Set 4 | marechal floriano
# Processing Record 45 of Set 4 | saint anthony
# Processing Record 46 of Set 4 | ribeira grande
# Processing Record 47 of Set 4 | east london
# Processing Record 48 of Set 4 | nanortalik
# Processing Record 49 of Set 4 | kruisfontein
# Processing Record 50 of Set 4 | bambous virieux
# Processing Record 1 of Set 5 | daxian
# City not found. Skipping...
# Processing Record 2 of Set 5 | plettenberg bay
# Processing Record 3 of Set 5 | lebu
# Processing Record 4 of Set 5 | tumen
# Processing Record 5 of Set 5 | touros
# Processing Record 6 of Set 5 | pogranichnyy
# Processing Record 7 of Set 5 | mokhsogollokh
# Processing Record 8 of Set 5 | fairbanks
# Processing Record 9 of Set 5 | geresk
# City not found. Skipping...
# Processing Record 10 of Set 5 | trelew
# Processing Record 11 of Set 5 | bethel
# Processing Record 12 of Set 5 | barrow
# Processing Record 13 of Set 5 | egvekinot
# Processing Record 14 of Set 5 | tuatapere
# Processing Record 15 of Set 5 | san ramon
# Processing Record 16 of Set 5 | jamiltepec
# Processing Record 17 of Set 5 | karasjok
# Processing Record 18 of Set 5 | puksoozero
# Processing Record 19 of Set 5 | inverness
# Processing Record 20 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 21 of Set 5 | te anau
# Processing Record 22 of Set 5 | katsuura
# Processing Record 23 of Set 5 | candolim
# Processing Record 24 of Set 5 | longlac
# City not found. Skipping...
# Processing Record 25 of Set 5 | asau
# Processing Record 26 of Set 5 | faanui
# Processing Record 27 of Set 5 | hervey bay
# Processing Record 28 of Set 5 | kavieng
# Processing Record 29 of Set 5 | sisophon
# Processing Record 30 of Set 5 | saint-joseph
# Processing Record 31 of Set 5 | beroroha
# Processing Record 32 of Set 5 | sorland
# Processing Record 33 of Set 5 | lompoc
# Processing Record 34 of Set 5 | hasaki
# Processing Record 35 of Set 5 | pallipattu
# Processing Record 36 of Set 5 | ponta do sol
# Processing Record 37 of Set 5 | ambon
# Processing Record 38 of Set 5 | talara
# Processing Record 39 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 40 of Set 5 | nchelenge
# Processing Record 41 of Set 5 | miri
# Processing Record 42 of Set 5 | matamoros
# Processing Record 43 of Set 5 | sinnamary
# Processing Record 44 of Set 5 | nemuro
# Processing Record 45 of Set 5 | cidreira
# Processing Record 46 of Set 5 | geraldton
# Processing Record 47 of Set 5 | kidal
# Processing Record 48 of Set 5 | iqaluit
# Processing Record 49 of Set 5 | zyryanka
# Processing Record 50 of Set 5 | razumnoye
# Processing Record 1 of Set 6 | charters towers
# Processing Record 2 of Set 6 | arys
# Processing Record 3 of Set 6 | porto novo
# Processing Record 4 of Set 6 | rawson
# Processing Record 5 of Set 6 | okhotsk
# Processing Record 6 of Set 6 | halalo
# City not found. Skipping...
# Processing Record 7 of Set 6 | ketchikan
# Processing Record 8 of Set 6 | cabo san lucas
# Processing Record 9 of Set 6 | galesong
# Processing Record 10 of Set 6 | igrim
# Processing Record 11 of Set 6 | llallagua
# Processing Record 12 of Set 6 | jacareacanga
# Processing Record 13 of Set 6 | berlevag
# Processing Record 14 of Set 6 | praia da vitoria
# Processing Record 15 of Set 6 | kirakira
# Processing Record 16 of Set 6 | vestbygda
# City not found. Skipping...
# Processing Record 17 of Set 6 | miraflores
# Processing Record 18 of Set 6 | batsfjord
# Processing Record 19 of Set 6 | lagoa
# Processing Record 20 of Set 6 | chokurdakh
# Processing Record 21 of Set 6 | ancud
# Processing Record 22 of Set 6 | ishigaki
# Processing Record 23 of Set 6 | wanning
# Processing Record 24 of Set 6 | nyurba
# Processing Record 25 of Set 6 | souillac
# Processing Record 26 of Set 6 | muros
# Processing Record 27 of Set 6 | beloha
# Processing Record 28 of Set 6 | tilichiki
# Processing Record 29 of Set 6 | ahipara
# Processing Record 30 of Set 6 | nouakchott
# Processing Record 31 of Set 6 | sistranda
# Processing Record 32 of Set 6 | ladario
# Processing Record 33 of Set 6 | chabahar
# Processing Record 34 of Set 6 | vila franca do campo
# Processing Record 35 of Set 6 | padang
# Processing Record 36 of Set 6 | prince rupert
# Processing Record 37 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 38 of Set 6 | huarmey
# Processing Record 39 of Set 6 | sheffield
# Processing Record 40 of Set 6 | alice springs
# Processing Record 41 of Set 6 | tura
# Processing Record 42 of Set 6 | iranshahr
# Processing Record 43 of Set 6 | rorvik
# Processing Record 44 of Set 6 | la ronge
# Processing Record 45 of Set 6 | vanderhoof
# Processing Record 46 of Set 6 | mabaruma
# Processing Record 47 of Set 6 | turukhansk
# Processing Record 48 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 49 of Set 6 | yulara
# Processing Record 50 of Set 6 | saskylakh
# Processing Record 1 of Set 7 | mackenzie
# Processing Record 2 of Set 7 | carnarvon
# Processing Record 3 of Set 7 | barawe
# City not found. Skipping...
# Processing Record 4 of Set 7 | constitucion
# Processing Record 5 of Set 7 | umm lajj
# Processing Record 6 of Set 7 | pingliang
# Processing Record 7 of Set 7 | yar-sale
# Processing Record 8 of Set 7 | baiquan
# Processing Record 9 of Set 7 | inta
# Processing Record 10 of Set 7 | naze
# Processing Record 11 of Set 7 | kosice
# Processing Record 12 of Set 7 | taltal
# Processing Record 13 of Set 7 | skiros
# City not found. Skipping...
# Processing Record 14 of Set 7 | eydhafushi
# Processing Record 15 of Set 7 | santa rosa
# Processing Record 16 of Set 7 | ilinsko-podomskoye
# City not found. Skipping...
# Processing Record 17 of Set 7 | itambacuri
# Processing Record 18 of Set 7 | surt
# Processing Record 19 of Set 7 | sitka
# Processing Record 20 of Set 7 | hermosillo
# Processing Record 21 of Set 7 | high level
# Processing Record 22 of Set 7 | christchurch
# Processing Record 23 of Set 7 | cockburn town
# Processing Record 24 of Set 7 | pokhara
# Processing Record 25 of Set 7 | mormugao
# Processing Record 26 of Set 7 | herat
# Processing Record 27 of Set 7 | zhigansk
# Processing Record 28 of Set 7 | eureka
# Processing Record 29 of Set 7 | ekuvukeni
# Processing Record 30 of Set 7 | miles city
# Processing Record 31 of Set 7 | adrar
# Processing Record 32 of Set 7 | umba
# Processing Record 33 of Set 7 | jian
# Processing Record 34 of Set 7 | kaitangata
# Processing Record 35 of Set 7 | baoning
# Processing Record 36 of Set 7 | kadyy
# Processing Record 37 of Set 7 | burgersdorp
# Processing Record 38 of Set 7 | hami
# Processing Record 39 of Set 7 | manadhoo
# Processing Record 40 of Set 7 | pokrovsk-uralskiy
# City not found. Skipping...
# Processing Record 41 of Set 7 | raudeberg
# Processing Record 42 of Set 7 | lata
# Processing Record 43 of Set 7 | asyut
# Processing Record 44 of Set 7 | guerrero negro
# Processing Record 45 of Set 7 | nanakuli
# Processing Record 46 of Set 7 | gamba
# Processing Record 47 of Set 7 | labuan
# Processing Record 48 of Set 7 | zuwarah
# Processing Record 49 of Set 7 | khandbari
# Processing Record 50 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 1 of Set 8 | haibowan
# City not found. Skipping...
# Processing Record 2 of Set 8 | araouane
# Processing Record 3 of Set 8 | palmer
# Processing Record 4 of Set 8 | georgetown
# Processing Record 5 of Set 8 | karoti
# Processing Record 6 of Set 8 | grindavik
# Processing Record 7 of Set 8 | biak
# Processing Record 8 of Set 8 | havoysund
# Processing Record 9 of Set 8 | mankono
# Processing Record 10 of Set 8 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 11 of Set 8 | kutum
# Processing Record 12 of Set 8 | tvedestrand
# Processing Record 13 of Set 8 | waipawa
# Processing Record 14 of Set 8 | sao joao da barra
# Processing Record 15 of Set 8 | vestmannaeyjar
# Processing Record 16 of Set 8 | kuusamo
# Processing Record 17 of Set 8 | mahibadhoo
# Processing Record 18 of Set 8 | rypefjord
# Processing Record 19 of Set 8 | airai
# Processing Record 20 of Set 8 | verkhnyaya inta
# Processing Record 21 of Set 8 | galle
# Processing Record 22 of Set 8 | scarborough
# Processing Record 23 of Set 8 | amahai
# Processing Record 24 of Set 8 | phuket
# Processing Record 25 of Set 8 | hunza
# City not found. Skipping...
# Processing Record 26 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 27 of Set 8 | castro
# Processing Record 28 of Set 8 | linjiang
# Processing Record 29 of Set 8 | rapid valley
# Processing Record 30 of Set 8 | ijaki
# City not found. Skipping...
# Processing Record 31 of Set 8 | lujan
# Processing Record 32 of Set 8 | khor
# Processing Record 33 of Set 8 | imeni poliny osipenko
# Processing Record 34 of Set 8 | khatanga
# Processing Record 35 of Set 8 | cam pha
# City not found. Skipping...
# Processing Record 36 of Set 8 | aykhal
# Processing Record 37 of Set 8 | khajuraho
# Processing Record 38 of Set 8 | mahebourg
# Processing Record 39 of Set 8 | naryan-mar
# Processing Record 40 of Set 8 | lake city
# Processing Record 41 of Set 8 | bichura
# Processing Record 42 of Set 8 | sola
# Processing Record 43 of Set 8 | andenes
# Processing Record 44 of Set 8 | lorengau
# Processing Record 45 of Set 8 | brae
# Processing Record 46 of Set 8 | arvika
# Processing Record 47 of Set 8 | moranbah
# Processing Record 48 of Set 8 | flinders
# Processing Record 49 of Set 8 | suez
# Processing Record 50 of Set 8 | san carlos de bariloche
# Processing Record 1 of Set 9 | los llanos de aridane
# Processing Record 2 of Set 9 | ejura
# Processing Record 3 of Set 9 | presidencia roque saenz pena
# Processing Record 4 of Set 9 | sisimiut
# Processing Record 5 of Set 9 | cervo
# Processing Record 6 of Set 9 | beringovskiy
# Processing Record 7 of Set 9 | karratha
# Processing Record 8 of Set 9 | chuy
# Processing Record 9 of Set 9 | kysyl-syr
# Processing Record 10 of Set 9 | chapais
# Processing Record 11 of Set 9 | pierre
# Processing Record 12 of Set 9 | agadir
# Processing Record 13 of Set 9 | toora-khem
# Processing Record 14 of Set 9 | rosarito
# Processing Record 15 of Set 9 | kaseda
# Processing Record 16 of Set 9 | tooele
# Processing Record 17 of Set 9 | deyang
# Processing Record 18 of Set 9 | ferrol
# Processing Record 19 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 20 of Set 9 | puerto madero
# Processing Record 21 of Set 9 | bulungu
# Processing Record 22 of Set 9 | repcelak
# Processing Record 23 of Set 9 | tsihombe
# City not found. Skipping...
# Processing Record 24 of Set 9 | mys shmidta
# City not found. Skipping...
# Processing Record 25 of Set 9 | zhanatas
# City not found. Skipping...
# Processing Record 26 of Set 9 | katherine
# Processing Record 27 of Set 9 | villazon
# Processing Record 28 of Set 9 | camp verde
# Processing Record 29 of Set 9 | tiksi
# Processing Record 30 of Set 9 | luocheng
# Processing Record 31 of Set 9 | ostrovnoy
# Processing Record 32 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 33 of Set 9 | pisco
# Processing Record 34 of Set 9 | pascagoula
# Processing Record 35 of Set 9 | matara
# Processing Record 36 of Set 9 | coquimbo
# Processing Record 37 of Set 9 | vardo
# Processing Record 38 of Set 9 | mahanoro
# Processing Record 39 of Set 9 | ossora
# Processing Record 40 of Set 9 | santa maria
# Processing Record 41 of Set 9 | samarai
# Processing Record 42 of Set 9 | klyuchi
# Processing Record 43 of Set 9 | tumpat
# Processing Record 44 of Set 9 | knysna
# Processing Record 45 of Set 9 | jujuy
# City not found. Skipping...
# Processing Record 46 of Set 9 | yingcheng
# Processing Record 47 of Set 9 | letlhakane
# Processing Record 48 of Set 9 | coari
# Processing Record 49 of Set 9 | kedougou
# Processing Record 50 of Set 9 | shelburne
# Processing Record 1 of Set 10 | fort nelson
# Processing Record 2 of Set 10 | puerto suarez
# Processing Record 3 of Set 10 | teguise
# Processing Record 4 of Set 10 | bardiyah
# Processing Record 5 of Set 10 | guacimo
# Processing Record 6 of Set 10 | kachhwa
# Processing Record 7 of Set 10 | aldan
# Processing Record 8 of Set 10 | thinadhoo
# Processing Record 9 of Set 10 | turtkul
# City not found. Skipping...
# Processing Record 10 of Set 10 | hoi an
# Processing Record 11 of Set 10 | seddon
# Processing Record 12 of Set 10 | moose factory
# Processing Record 13 of Set 10 | jalu
# Processing Record 14 of Set 10 | san felipe
# Processing Record 15 of Set 10 | japura
# Processing Record 16 of Set 10 | savinka
# Processing Record 17 of Set 10 | luganville
# Processing Record 18 of Set 10 | salihorsk
# Processing Record 19 of Set 10 | namatanai
# Processing Record 20 of Set 10 | maghama
# City not found. Skipping...
# Processing Record 21 of Set 10 | mackay
# Processing Record 22 of Set 10 | vyazma
# Processing Record 23 of Set 10 | hyeres
# Processing Record 24 of Set 10 | barao de melgaco
# Processing Record 25 of Set 10 | oriximina
# Processing Record 26 of Set 10 | terrace
# Processing Record 27 of Set 10 | itum-kale
# Processing Record 28 of Set 10 | chicama
# Processing Record 29 of Set 10 | vila velha
# Processing Record 30 of Set 10 | parintins
# Processing Record 31 of Set 10 | phan rang
# City not found. Skipping...
# Processing Record 32 of Set 10 | mana
# Processing Record 33 of Set 10 | north vanlaiphai
# Processing Record 34 of Set 10 | umm kaddadah
# Processing Record 35 of Set 10 | nuevitas
# Processing Record 36 of Set 10 | bonavista
# Processing Record 37 of Set 10 | tonshayevo
# Processing Record 38 of Set 10 | poum
# Processing Record 39 of Set 10 | zhanaozen
# Processing Record 40 of Set 10 | senneterre
# Processing Record 41 of Set 10 | orange cove
# Processing Record 42 of Set 10 | abrau-dyurso
# Processing Record 43 of Set 10 | kernersville
# Processing Record 44 of Set 10 | canon city
# Processing Record 45 of Set 10 | macheng
# Processing Record 46 of Set 10 | garissa
# Processing Record 47 of Set 10 | ust-nera
# Processing Record 48 of Set 10 | westpunt
# City not found. Skipping...
# Processing Record 49 of Set 10 | horsham
# Processing Record 50 of Set 10 | puerto escondido
# Processing Record 1 of Set 11 | baghmara
# Processing Record 2 of Set 11 | chernyshevskiy
# Processing Record 3 of Set 11 | lovington
# Processing Record 4 of Set 11 | praya
# Processing Record 5 of Set 11 | katobu
# Processing Record 6 of Set 11 | koungheul
# Processing Record 7 of Set 11 | cayenne
# Processing Record 8 of Set 11 | kozhva
# Processing Record 9 of Set 11 | nikolsk
# Processing Record 10 of Set 11 | muisne
# Processing Record 11 of Set 11 | tlanalapan
# Processing Record 12 of Set 11 | vulcan
# Processing Record 13 of Set 11 | ilo
# Processing Record 14 of Set 11 | lumphat
# Processing Record 15 of Set 11 | grand gaube
# Processing Record 16 of Set 11 | gushikawa
# Processing Record 17 of Set 11 | tawkar
# City not found. Skipping...
# Processing Record 18 of Set 11 | college
# Processing Record 19 of Set 11 | joshimath
# Processing Record 20 of Set 11 | hovd
# Processing Record 21 of Set 11 | bakhmach
# Processing Record 22 of Set 11 | byron bay
# Processing Record 23 of Set 11 | nishihara
# Processing Record 24 of Set 11 | marystown
# Processing Record 25 of Set 11 | kyzyl-suu
# Processing Record 26 of Set 11 | olafsvik
# Processing Record 27 of Set 11 | tezu
# Processing Record 28 of Set 11 | esperance
# Processing Record 29 of Set 11 | seoul
# Processing Record 30 of Set 11 | sindor
# Processing Record 31 of Set 11 | pontes e lacerda
# Processing Record 32 of Set 11 | port lincoln
# Processing Record 33 of Set 11 | filingue
# Processing Record 34 of Set 11 | krasnoselkup
# Processing Record 35 of Set 11 | chumikan
# Processing Record 36 of Set 11 | birstonas
# Processing Record 37 of Set 11 | olinda
# Processing Record 38 of Set 11 | rio grande
# Processing Record 39 of Set 11 | dongkan
# Processing Record 40 of Set 11 | yen bai
# Processing Record 41 of Set 11 | popondetta
# Processing Record 42 of Set 11 | makurdi
# Processing Record 43 of Set 11 | vanimo
# Processing Record 44 of Set 11 | roma
# Processing Record 45 of Set 11 | union
# Processing Record 46 of Set 11 | bull savanna
# Processing Record 47 of Set 11 | lake havasu city
# Processing Record 48 of Set 11 | mangaluru
# Processing Record 49 of Set 11 | kula
# Processing Record 50 of Set 11 | yerofey pavlovich
# Processing Record 1 of Set 12 | bathsheba
# Processing Record 2 of Set 12 | fukue
# Processing Record 3 of Set 12 | tricase
# Processing Record 4 of Set 12 | zharkent
# Processing Record 5 of Set 12 | cheuskiny
# City not found. Skipping...
# Processing Record 6 of Set 12 | mizdah
# Processing Record 7 of Set 12 | marsa matruh
# Processing Record 8 of Set 12 | hay river
# Processing Record 9 of Set 12 | birnin kebbi
# Processing Record 10 of Set 12 | deputatskiy
# Processing Record 11 of Set 12 | teguldet
# Processing Record 12 of Set 12 | odweyne
# Processing Record 13 of Set 12 | durban
# Processing Record 14 of Set 12 | quatre cocos
# Processing Record 15 of Set 12 | nuuk
# Processing Record 16 of Set 12 | obernai
# Processing Record 17 of Set 12 | aasiaat
# Processing Record 18 of Set 12 | kabinda
# Processing Record 19 of Set 12 | ayer itam
# City not found. Skipping...
# Processing Record 20 of Set 12 | jiddah
# City not found. Skipping...
# Processing Record 21 of Set 12 | roald
# Processing Record 22 of Set 12 | emden
# Processing Record 23 of Set 12 | kudahuvadhoo
# Processing Record 24 of Set 12 | duobao
# Processing Record 25 of Set 12 | mayahi
# Processing Record 26 of Set 12 | boundiali
# Processing Record 27 of Set 12 | madison
# Processing Record 28 of Set 12 | pilar
# Processing Record 29 of Set 12 | kaeo
# Processing Record 30 of Set 12 | mangalia
# Processing Record 31 of Set 12 | jauja
# Processing Record 32 of Set 12 | coihueco
# Processing Record 33 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 34 of Set 12 | narayanpet
# Processing Record 35 of Set 12 | coihaique
# Processing Record 36 of Set 12 | mnogovershinnyy
# Processing Record 37 of Set 12 | baglan
# Processing Record 38 of Set 12 | regina
# Processing Record 39 of Set 12 | vytegra
# Processing Record 40 of Set 12 | dandeli
# Processing Record 41 of Set 12 | vredendal
# Processing Record 42 of Set 12 | sobolevo
# Processing Record 43 of Set 12 | erzincan
# Processing Record 44 of Set 12 | ullapool
# Processing Record 45 of Set 12 | boa vista
# Processing Record 46 of Set 12 | richards bay
# Processing Record 47 of Set 12 | gambela
# Processing Record 48 of Set 12 | morondava
# Processing Record 49 of Set 12 | ucluelet
# Processing Record 50 of Set 12 | astipalaia
# City not found. Skipping...
# Processing Record 1 of Set 13 | yarmouth
# Processing Record 2 of Set 13 | san benito
# Processing Record 3 of Set 13 | bilma
# Processing Record 4 of Set 13 | tarbagatay
# Processing Record 5 of Set 13 | palora
# Processing Record 6 of Set 13 | road town
# Processing Record 7 of Set 13 | yumen
# Processing Record 8 of Set 13 | ozinki
# Processing Record 9 of Set 13 | mandalgovi
# Processing Record 10 of Set 13 | chuguyevka
# Processing Record 11 of Set 13 | nanpiao
# Processing Record 12 of Set 13 | tessalit
# Processing Record 13 of Set 13 | killybegs
# Processing Record 14 of Set 13 | san patricio
# Processing Record 15 of Set 13 | ponta delgada
# Processing Record 16 of Set 13 | ust-maya
# Processing Record 17 of Set 13 | tiznit
# Processing Record 18 of Set 13 | babanka
# Processing Record 19 of Set 13 | homer
# Processing Record 20 of Set 13 | waddan
# Processing Record 21 of Set 13 | namtsy
# Processing Record 22 of Set 13 | kupang
# Processing Record 23 of Set 13 | itarema
# Processing Record 24 of Set 13 | batagay-alyta
# Processing Record 25 of Set 13 | kismayo
# Processing Record 26 of Set 13 | sal rei
# Processing Record 27 of Set 13 | kefamenanu
# Processing Record 28 of Set 13 | bulakamba
# Processing Record 29 of Set 13 | obo
# Processing Record 30 of Set 13 | doka
# Processing Record 31 of Set 13 | oranjemund
# Processing Record 32 of Set 13 | canutama
# Processing Record 33 of Set 13 | batemans bay
# Processing Record 34 of Set 13 | munak
# Processing Record 35 of Set 13 | pakxan
# Processing Record 36 of Set 13 | rivadavia
# Processing Record 37 of Set 13 | monte patria
# Processing Record 38 of Set 13 | vazante
# Processing Record 39 of Set 13 | tartus
# Processing Record 40 of Set 13 | dongzhen
# Processing Record 41 of Set 13 | kinsale
# Processing Record 42 of Set 13 | omboue
# Processing Record 43 of Set 13 | lewisville
# Processing Record 44 of Set 13 | meyungs
# City not found. Skipping...
# Processing Record 45 of Set 13 | solnechnyy
# Processing Record 46 of Set 13 | dubbo
# Processing Record 47 of Set 13 | ambilobe
# Processing Record 48 of Set 13 | samusu
# City not found. Skipping...
# Processing Record 49 of Set 13 | dolbeau
# City not found. Skipping...
# Processing Record 50 of Set 13 | saldanha
# Processing Record 1 of Set 14 | morro bay
# Processing Record 2 of Set 14 | qurayyat
# Processing Record 3 of Set 14 | oktyabrskiy
# Processing Record 4 of Set 14 | uk
# City not found. Skipping...
# Processing Record 5 of Set 14 | bintulu
# Processing Record 6 of Set 14 | conakry
# Processing Record 7 of Set 14 | riyadh
# Processing Record 8 of Set 14 | asosa
# Processing Record 9 of Set 14 | hesla
# Processing Record 10 of Set 14 | tuggurt
# City not found. Skipping...
# Processing Record 11 of Set 14 | visby
# Processing Record 12 of Set 14 | porto santo
# Processing Record 13 of Set 14 | karamea
# City not found. Skipping...
# Processing Record 14 of Set 14 | cururupu
# Processing Record 15 of Set 14 | gra liyia
# Processing Record 16 of Set 14 | tolaga bay
# Processing Record 17 of Set 14 | fortuna
# Processing Record 18 of Set 14 | talcahuano
# Processing Record 19 of Set 14 | elk river
# Processing Record 20 of Set 14 | siyabuswa
# Processing Record 21 of Set 14 | harsin
# Processing Record 22 of Set 14 | bolshiye uki
# City not found. Skipping...
# Processing Record 23 of Set 14 | pitimbu
# Processing Record 24 of Set 14 | shimoda
# Processing Record 25 of Set 14 | minab
# Processing Record 26 of Set 14 | baruun-urt
# Processing Record 27 of Set 14 | punta alta
# Processing Record 28 of Set 14 | boizenburg
# Processing Record 29 of Set 14 | galiwinku
# City not found. Skipping...
# Processing Record 30 of Set 14 | burley
# Processing Record 31 of Set 14 | povenets
# Processing Record 32 of Set 14 | yenagoa
# Processing Record 33 of Set 14 | nongstoin
# Processing Record 34 of Set 14 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 35 of Set 14 | asilah
# Processing Record 36 of Set 14 | pacific grove
# Processing Record 37 of Set 14 | antalya
# Processing Record 38 of Set 14 | bara
# Processing Record 39 of Set 14 | axim
# Processing Record 40 of Set 14 | telimele
# Processing Record 41 of Set 14 | sonoita
# Processing Record 42 of Set 14 | yerbogachen
# Processing Record 43 of Set 14 | kiomboi
# Processing Record 44 of Set 14 | banapur
# Processing Record 45 of Set 14 | tazovskiy
# Processing Record 46 of Set 14 | marfino
# Processing Record 47 of Set 14 | lasa
# Processing Record 48 of Set 14 | blackwater
# Processing Record 49 of Set 14 | montrose
# Processing Record 50 of Set 14 | codrington
# Processing Record 1 of Set 15 | krasnyy kommunar
# Processing Record 2 of Set 15 | terre-de-bas
# Processing Record 3 of Set 15 | margate
# Processing Record 4 of Set 15 | bahia blanca
# Processing Record 5 of Set 15 | lucapa
# Processing Record 6 of Set 15 | annau
# Processing Record 7 of Set 15 | kholodnyy
# Processing Record 8 of Set 15 | port hawkesbury
# Processing Record 9 of Set 15 | yura
# Processing Record 10 of Set 15 | nhulunbuy
# Processing Record 11 of Set 15 | ixtapa
# Processing Record 12 of Set 15 | inuvik
# Processing Record 13 of Set 15 | westport
# Processing Record 14 of Set 15 | ternate
# Processing Record 15 of Set 15 | corrientes
# Processing Record 16 of Set 15 | haines junction
# Processing Record 17 of Set 15 | jumla
# Processing Record 18 of Set 15 | umm bab
# Processing Record 19 of Set 15 | necochea
# Processing Record 20 of Set 15 | viedma
# Processing Record 21 of Set 15 | vaasa
# Processing Record 22 of Set 15 | maltahohe
# Processing Record 23 of Set 15 | juneau
# Processing Record 24 of Set 15 | muriwai beach
# Processing Record 25 of Set 15 | pula
# Processing Record 26 of Set 15 | litoral del san juan
# City not found. Skipping...
# Processing Record 27 of Set 15 | garmsar
# Processing Record 28 of Set 15 | pitogo
# Processing Record 29 of Set 15 | preobrazheniye
# Processing Record 30 of Set 15 | sakakah
# Processing Record 31 of Set 15 | sungaipenuh
# Processing Record 32 of Set 15 | maceio
# Processing Record 33 of Set 15 | schotten
# Processing Record 34 of Set 15 | lamu
# Processing Record 35 of Set 15 | omsukchan
# Processing Record 36 of Set 15 | saint-francois
# Processing Record 37 of Set 15 | otane
# Processing Record 38 of Set 15 | socorro
# Processing Record 39 of Set 15 | kaele
# Processing Record 40 of Set 15 | moindou
# Processing Record 41 of Set 15 | monze
# Processing Record 42 of Set 15 | uyuni
# Processing Record 43 of Set 15 | birao
# Processing Record 44 of Set 15 | shieli
# Processing Record 45 of Set 15 | teya
# Processing Record 46 of Set 15 | havelock
# Processing Record 47 of Set 15 | broome
# Processing Record 48 of Set 15 | saryshagan
# City not found. Skipping...
# Processing Record 49 of Set 15 | jawhar
# Processing Record 50 of Set 15 | kiama
# Processing Record 1 of Set 16 | alta floresta
# Processing Record 2 of Set 16 | mundo nuevo
# Processing Record 3 of Set 16 | smithers
# Processing Record 4 of Set 16 | boende
# Processing Record 5 of Set 16 | sombrio
# Processing Record 6 of Set 16 | nabire
# Processing Record 7 of Set 16 | kaiyuan
# Processing Record 8 of Set 16 | manjakandriana
# Processing Record 9 of Set 16 | agadez
# Processing Record 10 of Set 16 | mazyr
# Processing Record 11 of Set 16 | kikwit
# Processing Record 12 of Set 16 | wagar
# Processing Record 13 of Set 16 | kano
# Processing Record 14 of Set 16 | sao jose da coroa grande
# Processing Record 15 of Set 16 | marcona
# City not found. Skipping...
# Processing Record 16 of Set 16 | binabalian
# Processing Record 17 of Set 16 | guatire
# Processing Record 18 of Set 16 | varkaus
# Processing Record 19 of Set 16 | orotukan
# Processing Record 20 of Set 16 | gravdal
# Processing Record 21 of Set 16 | manzanillo
# Processing Record 22 of Set 16 | north bend
# Processing Record 23 of Set 16 | zhangzhou
# Processing Record 24 of Set 16 | la roda
# Processing Record 25 of Set 16 | barentu
# Processing Record 26 of Set 16 | kuche
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 714

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Hobyo      SO   5.3505   48.5268     77.00        75          11
# 1      Bredasdorp      ZA -34.5322   20.0403     62.28        89           0
# 2            Tual      ID  -5.6667  132.7500     83.43        78         100
# 3    Norman Wells      CA  65.2820 -126.8329     -2.36        96         100
# 4     Tuktoyaktuk      CA  69.4541 -133.0374     -7.24        97         100
# 5          Dikson      RU  73.5069   80.5464    -14.21        80         100
# 6         Ushuaia      AR -54.8000  -68.3000     46.02        90         100
# 7          Albany      US  42.6001  -73.9662     36.81        78          92
# 8     Henties Bay      NA -22.1160   14.2845     57.85        89          58
# 9  Port Elizabeth      ZA -33.9180   25.5701     69.10       100          90
#
#    Wind Speed      Description
# 0       16.33       few clouds
# 1        7.61        clear sky
# 2       16.96  overcast clouds
# 3        0.98  overcast clouds
# 4        6.29  overcast clouds
# 5        2.59  overcast clouds
# 6        3.56  overcast clouds
# 7        2.82  overcast clouds
# 8        4.79    broken clouds
# 9       10.36  overcast clouds

# %%
# Export the City_Data into a CSV.
city_data_df.to_csv("WeatherPy_Database.csv",index_label="City_ID")
